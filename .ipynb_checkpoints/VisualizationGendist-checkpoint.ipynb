# %%
import sys
# setting path

import copy
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.lines as mlines 
import copy
from argparse import ArgumentParser
import time
import pickle

from Models.Caller64 import *
from Benchmarks.Models.BenchmarkCaller64 import ModelCall as BMCaller
from Benchmarks.Models.DiffWave64 import DiffWAVE_Restoration, determine_gen_steps_diffwave
from Benchmarks.Models.VDiffWave64 import VDiffWAVE_Restoration, determine_gen_steps_vdwave

from Utilities.AncillaryFunctions64 import FFT_PSD, GenConArangeSimple, compute_snr, scale_and_normalize
from Utilities.Utilities import ReadYaml, SerializeObjects, DeserializeObjects, LoadModelConfigs, LoadParams, ReadYaml


from tqdm import trange, tqdm
import itertools
from scipy.stats import mode

import tensorflow as tf
tf.keras.backend.set_floatx('float64')

# %% [markdown]
# ## Signal Generation and PSD/KLD Analysis Pipeline for SKZ, VAE, and Diffusion Models

# %%
# =============================================================================
# Helper Functions
# =============================================================================

def compute_kld_divergence(P, Q):
    """
    Compute the symmetric Kullback-Leibler divergence between two PSD distributions.
    
    Parameters:
        P (np.array): PSD of the generated signal.
        Q (np.array): PSD of the reference signal.
    
    Returns:
        np.array: The symmetric KLD value.
    """
    return (np.sum(P * np.log(P / Q), axis=-1) + np.sum(Q * np.log(Q / P), axis=-1)) / 2

def get_frequency_categories(pdf_data, num_groups=5):
    """
    Extract dominant frequency indices from PDF data and split them into groups.
    
    Parameters:
        pdf_data (np.array): PDF data (e.g. AnalData[1]).
        num_groups (int): Number of groups to split the unique indices.
    
    Returns:
        tuple: (argmax_indices, sorted_idx_array, fc_groups)
            - argmax_indices: The index of the maximum value per sample.
            - sorted_idx_array: A 2D array of sorted indices and corresponding values.
            - fc_groups: List of frequency category groups.
    """
    argmax_indices = np.argmax(pdf_data, axis=-1)
    sorted_idx = np.argsort(argmax_indices)
    sorted_idx_array = np.column_stack((sorted_idx, argmax_indices[sorted_idx]))
    unique_vals = np.unique(argmax_indices)
    fc_groups = np.array_split(unique_vals, num_groups)
    return argmax_indices, sorted_idx_array, fc_groups

def get_selected_indices(argmax_indices, fc_group, eval_size):
    """
    From the specified frequency group select sample indices within a defined range.
    
    Parameters:
        argmax_indices (np.array): Array of argmax indices.
        fc_group (np.array): One frequency category group.
        eval_size (int): Number of indices to select.
    
    Returns:
        np.array: Randomly chosen indices meeting the frequency condition.
    """
    idx_condition = np.where((argmax_indices > fc_group.min() - 1) & (argmax_indices <= fc_group.max()))[0]
    selected_indices = np.random.choice(argmax_indices[idx_condition], size=eval_size, replace=True)
    return selected_indices


# =============================================================================
# Processing Functions for Each Model Type
# =============================================================================

def process_SKZ(AnalData, Params, GenModel, Encoder, fc_ranges):
    """
    Process data for the 'SKZ' branch.
    
    In this branch, frequency control predictors (FCPred) are replaced with random values
    over specified ranges. The generator then uses these modified predictors along with
    latent variables to produce a signal.
    
    Returns:
        list: Collection of FFT-based PSD arrays for each fc range.
    """
    resP = []  # Local list to store PSD results
    first_part_size = GenModel.input[0].shape[-1]
    ZPred, FCPred = Encoder.predict(AnalData, batch_size=1000)
    
    for low_fc, high_fc in fc_ranges:
        # Replace FCPred with random values within the current range
        FCPred_rand = np.random.uniform(low=low_fc, high=high_fc, size=FCPred.shape)
        
        # Split frequency control predictors into two parts based on model input size
        if first_part_size == 0:
            fc_first = np.zeros((Params['EvalDataSize'], 0))
            fc_second = FCPred_rand
        else:
            fc_first = FCPred_rand[:, :first_part_size]
            fc_second = FCPred_rand[:, first_part_size:]
        
        # Generate signal using the modified predictors and latent variables
        GenSig = GenModel.predict([fc_first, fc_second, ZPred], batch_size=1000)
        
        # Compute PSDs and symmetric KLD divergence
        P = FFT_PSD(GenSig, ReducedAxis='All', method='fft')
        Q = FFT_PSD(AnalData, ReducedAxis='All', method='fft')
        kld_result = compute_kld_divergence(P, Q)
        
        # Append generated signal PSD to results list
        resP.append(P)
        plt.plot(P)
    
    # Plot the analytical signal PSD in red for reference
    plt.plot(FFT_PSD(AnalData, ReducedAxis='All', method='fft'), c='red')
    return resP, Q

def process_VAE(AnalData, Params, GenModel, SampZModel):
    """
    Process data for the 'VAE' branch.
    
    Latent representations are obtained via a VAE model and frequency categories 
    are determined from PDF data. For each frequency group, a subset is selected and used 
    to generate signals.
    
    Returns:
        list: Collection of FFT-based PSD arrays for each frequency category.
    """
    resP = []
    ZPred = SampZModel.predict(AnalData, batch_size=1000)
    
    # Obtain frequency categories from the PDF data (Assumed to be AnalData[1])
    argmax_indices, _, fc_groups = get_frequency_categories(AnalData[1], num_groups=5)
    
    for fc in fc_groups:
        sel_idx = get_selected_indices(argmax_indices, fc, Params['EvalDataSize'])
        GenSig = GenModel.predict([ZPred, AnalData[1][sel_idx]], batch_size=1000)
        
        # Compute PSDs and append to result list
        P = FFT_PSD(GenSig, ReducedAxis='All', method='fft')
        Q = FFT_PSD(AnalData[0], ReducedAxis='All', method='fft')
        kld_result = compute_kld_divergence(P, Q)
        resP.append(P)
        plt.plot(P)
    
    # Plot ground truth PSD in red
    plt.plot(FFT_PSD(AnalData[0], ReducedAxis='All', method='fft'), c='red')
    return resP, Q

def process_DiffWave(AnalData, Params, GenModel, SigmaSig, MeanSig, SigMin, SigMax):
    """
    Process data for the 'DiffWave' branch.
    
    This branch uses a diffusion process to restore signals. It determines the number of 
    diffusion steps based on an SNR threshold, restores the signal, scales it, computes the PSD, 
    and collects the results.
    
    Returns:
        list: Collection of FFT-based PSD arrays (one per frequency category).
    """
    resP = []
    argmax_indices, _, fc_groups = get_frequency_categories(AnalData[1], num_groups=5)
    
    for num, fc in enumerate(fc_groups):
        print(num, fc)
        sel_idx = get_selected_indices(argmax_indices, fc, Params['EvalDataSize'])
        GenSteps, noise = determine_gen_steps_diffwave(AnalData[0], GenModel, Params['Iter'], 
                                                       Params['GaussSigma'], Params['SNR_cutoff'])
        
        # Perform diffusion with determined steps and restore the signal
        diffused, _ = GenModel.diffusion(AnalData[0], GenModel.alpha_bar[GenSteps].item(), noise)
        GenSig = DiffWAVE_Restoration(GenModel, diffused, AnalData[1][sel_idx],
                                      GenBatchSize=1000, GenSteps=GenSteps, StepInterval=Params['StepInterval'])
        
        # Scale and normalize the restored signal and ground truth
        GenSig_norm = scale_and_normalize(GenSig, SigmaSig, MeanSig, 
                                          SigMin[Params['SigType']], SigMax[Params['SigType']])
        GroundTruth = scale_and_normalize(AnalData[0], SigmaSig, MeanSig,
                                          SigMin[Params['SigType']], SigMax[Params['SigType']])
        
        # Compute PSD and append to result list (using extra dimension as in original)
        P = FFT_PSD(GenSig_norm, ReducedAxis='All', method='fft')
        Q = FFT_PSD(GroundTruth, ReducedAxis='All', method='fft')
        _ = compute_kld_divergence(P, Q)  # kld_result computed if needed for evaluation
        resP.append(P[None])
        plt.plot(P)
    
    # Plot the ground truth PSD in red for comparison
    plt.plot(FFT_PSD(GroundTruth, ReducedAxis='All', method='fft'), c='red')
    return resP, Q

def process_VDWave(AnalData, Params, GenModel, SigmaSig, MeanSig, SigMin, SigMax):
    """
    Process data for the 'VDWave' branch.
    
    This branch uses a variable diffusion approach. The appropriate generation steps 
    are determined based on SNR thresholds using a sampling method. The signal is restored, 
    scaled, its PSD computed, and the results are collected.
    
    Returns:
        list: Collection of FFT-based PSD arrays (one per frequency category).
    """
    resP = []
    argmax_indices, _, fc_groups = get_frequency_categories(AnalData[1], num_groups=5)
    
    for num, fc in enumerate(fc_groups):
        print(num, fc)
        sel_idx = get_selected_indices(argmax_indices, fc, Params['EvalDataSize'])
        GenSteps, t_float, noise = determine_gen_steps_vdwave(AnalData[0], GenModel, Params['Iter'], 
                                                               Params['SNR_cutoff'])
        
        diffused, _, noise = GenModel.sample_q_t_0(AnalData[0], t_float, None, gamma_t=None)
        GenSig = VDiffWAVE_Restoration(GenModel, diffused[0][..., None], AnalData[1],
                                      GenSteps, GenModel.cfg['StepInterval'], GenBatchSize=Params['GenBatchSize'])
        
        GenSig_norm = scale_and_normalize(GenSig, SigmaSig, MeanSig, 
                                          SigMin[Params['SigType']], SigMax[Params['SigType']])
        GroundTruth = scale_and_normalize(AnalData[0], SigmaSig, MeanSig,
                                          SigMin[Params['SigType']], SigMax[Params['SigType']])
        
        P = FFT_PSD(np.squeeze(GenSig_norm), ReducedAxis='All', method='fft')
        Q = FFT_PSD(GroundTruth, ReducedAxis='All', method='fft')
        _ = compute_kld_divergence(P, Q)
        resP.append(P[None])
        plt.plot(P)
    
    plt.plot(FFT_PSD(GroundTruth, ReducedAxis='All', method='fft'), c='red')
    return resP, Q

# %% [markdown]
# ## Main Evaluation Loop for Multi-Model Execution and Result Serialization

# %%
DicConfigYaml = { 
    'ART_VitalDB' : {'SKZFC_ART_1_30_800_VitalDB':   './Config/EvalConfigVitalDB.yml',              
                     'VDWave_ART_VitalDB':   './Benchmarks/Config/EvalConfigART_Other.yml', 
                     'VDVAE_ART_30_VitalDB':   './Benchmarks/Config/EvalConfigART_VAE.yml'},
   
    'ART_Mimic' : {'SKZFC_ART_1_30_800_Mimic':   './Config/EvalConfigMimic.yml',              
                     'VDWave_ART_Mimic':   './Benchmarks/Config/EvalConfigART_Other.yml', 
                     'VDVAE_ART_30_Mimic':   './Benchmarks/Config/EvalConfigART_VAE.yml'},
    
    'II_VitalDB' : {'SKZFC_II_1_30_800_VitalDB':   './Config/EvalConfigVitalDB.yml',              
                     'VDWave_II_VitalDB':   './Benchmarks/Config/EvalConfigII_Other.yml', 
                     'VDVAE_II_30_VitalDB':   './Benchmarks/Config/EvalConfigII_VAE.yml'},
    
    'II_Mimic' : {'SKZFC_II_1_30_800_Mimic':   './Config/EvalConfigMimic.yml',              
                     'VDWave_II_Mimic':   './Benchmarks/Config/EvalConfigII_Other.yml', 
                     'VDVAE_II_30_Mimic':   './Benchmarks/Config/EvalConfigII_VAE.yml'}    }



# Define frequency control ranges for the SKZ branch
FC_RANGES = [[0, 0.2], [0.2, 0.4], [0.4, 0.6], [0.6, 0.8], [0.8, 1.0]]

DicPList = copy.deepcopy(DicConfigYaml)
DicQ = copy.deepcopy(DicConfigYaml)

for UpKey in DicConfigYaml.keys():
    for DnKey in DicConfigYaml[UpKey]:
        EvalConfigs = ReadYaml(DicConfigYaml[UpKey][DnKey])
        print(DnKey, DicConfigYaml[UpKey][DnKey])
        if 'SKZ' in DnKey:
            ModelConfigSet, ModelLoadName = LoadModelConfigs(DnKey)
        else:
            ModelConfigSet, ModelLoadName = LoadModelConfigs(DnKey, Comp=False, TypeDesig=True, RootDirYaml='./Benchmarks/Config/', RootDirRes=None)

        if 'SKZ' in DnKey:
            # Loading parameters for the evaluation
            Params = LoadParams(ModelConfigSet, EvalConfigs['Parameters'])
            Params['Common_Info'] = EvalConfigs['Common_Info']
        else:
            CommonParams = EvalConfigs['Common_Param']
            ModelParams = EvalConfigs["Models"][DnKey]
            Params = LoadParams(ModelConfigSet, {**CommonParams, **ModelParams})
            Params['Common_Info'] = EvalConfigs['Common_Info']


        # Loading data
        AnalData = np.load('./Data/ProcessedData/'+str(Params['TestDataSource'])+'Test'+str(Params['SigType'])+'.npy').astype('float64')[:Params['EvalDataSize']]
        
        # Intermediate parameters 
        SigDim = AnalData.shape[1]
        Params['DataSize'] = Params['EvalDataSize']

        
        if 'SKZ' in DnKey: 
            # Calling Modesl
            SigRepModel, ModelParts = ModelCall (ModelConfigSet, SigDim, Params['DataSize'], LoadWeight=True, ReturnModelPart=True, 
                                                 ReparaStd=Params['ReparaStd'], ModelSaveName=ModelLoadName, Reparam=False)

            # Setting Model Specifications and Sub-models
            if Params['LossType'] =='Default':
                EncModel, FeatExtModel, FeatGenModel, ReconModel = ModelParts
            elif Params['LossType'] =='FACLosses':
                EncModel, FeatExtModel, FeatGenModel, ReconModel, FacDiscModel = ModelParts
            
            
            ## The generation model for evaluation
            RecOut = ReconModel(FeatGenModel.output)
            GenModel = Model(FeatGenModel.input, RecOut)
            Encoder = Model(SigRepModel.get_layer('Inp_Enc').input, [SigRepModel.get_layer('Zs').output, SigRepModel.get_layer('FCs').output])

            resP, Q = process_SKZ(AnalData, Params, GenModel, Encoder, FC_RANGES)
            
        elif 'VAE' in DnKey:
            TrData = np.load('./Data/ProcessedData/'+str(Params['DataSource'])+'Tr'+str(Params['SigType'])+'.npy').astype('float64')
            BenchModel, _, AnalData = BMCaller (Params, DnKey, TrData, AnalData, LoadWeight=True, Reparam=False, 
                                                ReparaStd=Params['ReparaStd'], ModelSaveName='./Benchmarks/' + ModelLoadName[2:])

            ## The generation model for evaluation
            GenModel = BenchModel.get_layer('ReconModel')

            ## The sampling model for evaluation
            Inp_Enc = BenchModel.get_layer('Inp_Enc')
            
            if 'VDV' in DnKey:
                Zs = tf.concat([BenchModel.get_layer('Zs'+str(i)).output for i in range(len(Params['LatDim']))], axis=-1)
            else:
                Zs = BenchModel.get_layer('Zs').output
            Inp_Cond = BenchModel.get_layer('Inp_Cond')
            SampZModel = Model([Inp_Enc.input, Inp_Cond.input], Zs)

            resP, Q = process_VAE(AnalData, Params, GenModel, SampZModel)

        elif 'DiffWave' in DnKey or 'VDWave' in DnKey:
            TrData = np.load('./Data/ProcessedData/'+str(Params['DataSource'])+'Tr'+str(Params['SigType'])+'.npy').astype('float64')
            SigMax = np.load('./Data/ProcessedData/'+str(Params['DataSource'])+'SigMax.pkl', allow_pickle=True)
            SigMin = np.load('./Data/ProcessedData/'+str(Params['DataSource'])+'SigMin.pkl', allow_pickle=True)
            
            TrDeNorm = (TrData * (SigMax[Params['SigType']] - SigMin[Params['SigType']]) + SigMin[Params['SigType']]).copy()
            ValDeNorm = (AnalData * (SigMax[Params['SigType']] - SigMin[Params['SigType']]) + SigMin[Params['SigType']]).copy()
            
            MeanSig, SigmaSig = np.mean(TrDeNorm), np.std(TrDeNorm) 
            TrInp = (TrDeNorm-MeanSig)/SigmaSig
            ValInp = (ValDeNorm-MeanSig)/SigmaSig

            GenModel, _, AnalData = BMCaller (Params, DnKey, TrInp, ValInp, LoadWeight = True, ModelSaveName='./Benchmarks/' + ModelLoadName[2:])      

            if 'DiffWave' in DnKey:
                resP, Q = process_DiffWave(AnalData, Params, GenModel, SigmaSig, MeanSig, SigMin, SigMax)
            elif 'VDWave' in DnKey:
                resP, Q = process_VDWave(AnalData, Params, GenModel, SigmaSig, MeanSig, SigMin, SigMax)

        DicPList[UpKey][DnKey] = resP 
        DicQ[UpKey][DnKey] = Q


# Save to file
with open("./EvalResults/Instances/DicPList.pkl", "wb") as f:
    pickle.dump(DicPList, f)

with open("./EvalResults/Instances/DicQ.pkl", "wb") as f:
    pickle.dump(DicQ, f)
# Out:
# SKZFC_ART_1_30_800_VitalDB ./Config/EvalConfigVitalDB.yml
# OrigRecLoss added
# FeatRecLoss added
# kl_Loss_SKZ selected
# kl_Loss_Z added
# kl_Loss_FC added
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame (TFOpLambda)   (None, 20, 50)       0           ['Inp_Enc[0][0]']
#
#  bidirectional (Bidirectional)  (None, 20, 50)       11550       ['tf.signal.frame[0][0]']
#
#  bidirectional_1 (Bidirectional  (None, 20, 50)      11550       ['bidirectional[0][0]']
#  )
#
#  bidirectional_2 (Bidirectional  (None, 150)         57150       ['bidirectional_1[0][0]']
#  )
#
#  dense (Dense)                  (None, 100)          15100       ['bidirectional_2[0][0]']
#
#  dense_1 (Dense)                (None, 70)           7070        ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 50)           3550        ['dense_1[0][0]']
#
#  dense_4 (Dense)                (None, 2)            102         ['dense_2[0][0]']
#
#  dense_5 (Dense)                (None, 2)            6           ['dense_4[0][0]']
#
#  tf.clip_by_value (TFOpLambda)  (None, 2)            0           ['dense_5[0][0]']
#
#  FC_Mu (Lambda)                 (None, 2)            0           ['tf.clip_by_value[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (2,)                0           ['FC_Mu[0][0]']
#  da)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.random.uniform (TFOpLambda)  (None, 2)           0           ['tf.__operators__.getitem_1[0][0
#                                                                  ]']
#
#  tf.cast_1 (TFOpLambda)         (None, 2)            0           ['tf.random.uniform[0][0]']
#
#  tf.clip_by_value_1 (TFOpLambda  (None, 2)           0           ['tf.cast_1[0][0]']
#  )
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.clip_by_value_1[0][0]']
#
#  tf.math.log (TFOpLambda)       (None, 2)            0           ['tf.clip_by_value_1[0][0]']
#
#  tf.math.log_1 (TFOpLambda)     (None, 2)            0           ['tf.math.subtract[0][0]']
#
#  tf.math.subtract_2 (TFOpLambda  (None, 2)           0           ['tf.math.log[0][0]',
#  )                                                                'tf.math.log_1[0][0]']
#
#  tf.math.log_2 (TFOpLambda)     (None, 2)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['FC_Mu[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (None, 2)           0           ['tf.math.subtract_2[0][0]',
#  mbda)                                                            'tf.math.log_2[0][0]']
#
#  tf.math.log_3 (TFOpLambda)     (None, 2)            0           ['tf.math.subtract_1[0][0]']
#
#  Z_Mu (Dense)                   (None, 30)           1530        ['dense_2[0][0]']
#
#  tf.math.subtract_3 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_1[0][0]',
#  )                                                                'tf.math.log_3[0][0]']
#
#  tf.compat.v1.shape (TFOpLambda  (2,)                0           ['Z_Mu[0][0]']
#  )
#
#  tf.math.sigmoid (TFOpLambda)   (None, 2)            0           ['tf.math.subtract_3[0][0]']
#
#  dense_3 (Dense)                (None, 30)           1530        ['dense_2[0][0]']
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.math.multiply_3 (TFOpLambda  (None, 2)           0           ['tf.math.sigmoid[0][0]']
#  )
#
#  tf.math.multiply_4 (TFOpLambda  (None, 2)           0           ['FC_Mu[0][0]']
#  )
#
#  Z_Log_Sigma (Lambda)           (None, 30)           0           ['dense_3[0][0]']
#
#  tf.random.normal (TFOpLambda)  (None, 30)           0           ['tf.__operators__.getitem[0][0]'
#                                                                  ]
#
#  tf.__operators__.add_2 (TFOpLa  (None, 2)           0           ['tf.math.multiply_3[0][0]',
#  mbda)                                                            'tf.math.multiply_4[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 30)          0           ['Z_Log_Sigma[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (None, 30)           0           ['tf.random.normal[0][0]']
#
#  tf.math.multiply_5 (TFOpLambda  (None, 2)           0           ['tf.__operators__.add_2[0][0]']
#  )
#
#  tf.math.exp (TFOpLambda)       (None, 30)           0           ['tf.math.multiply_1[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 30)           0           ['tf.math.multiply[0][0]']
#
#  tf.clip_by_value_2 (TFOpLambda  (None, 2)           0           ['tf.math.multiply_5[0][0]']
#  )
#
#  tf.math.multiply_2 (TFOpLambda  (None, 30)          0           ['tf.math.exp[0][0]',
#  )                                                                'tf.cast[0][0]']
#
#  FCs (Lambda)                   (None, 2)            0           ['tf.clip_by_value_2[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 30)          0           ['Z_Mu[0][0]',
#  da)                                                              'tf.math.multiply_2[0][0]']
#
#  tf.__operators__.getitem_12 (S  (None, 0)           0           ['FCs[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  (None, 2)           0           ['FCs[0][0]']
#  licingOpLambda)
#
#  Zs (Lambda)                    (None, 30)           0           ['tf.__operators__.add[0][0]']
#
#  SigOut (Flatten)               (None, 1000)         0           ['tf.signal.frame[0][0]']
#
#  FeatGenModel (Functional)      [(None, 800),        40850       ['tf.__operators__.getitem_12[0][
#                                  (None, 800)]                    0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 800),        0           ['SigOut[0][0]',
#                                  (None, 800)]                     'FCs[0][0]']
#
#  ReconModel (Functional)        (None, 1000)         84900       ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]']
#
#  tf.cast_9 (TFOpLambda)         (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_8 (TFOpLambda)         (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_4 (TFOpLambda  (None, 1000)        0           ['tf.cast_9[0][0]',
#  )                                                                'tf.cast_8[0][0]']
#
#  Beta_Orig (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 1000)         0           ['tf.math.subtract_4[0][0]']
#
#  tf.cast_6 (TFOpLambda)         ()                   0           ['Beta_Orig[0][0]']
#
#  tf.math.reduce_mean (TFOpLambd  ()                  0           ['tf.math.square[0][0]']
#  a)
#
#  tf.math.multiply_18 (TFOpLambd  ()                  0           ['tf.cast_6[0][0]',
#  a)                                                               'tf.math.reduce_mean[0][0]']
#
#  add_loss (AddLoss)             ()                   0           ['tf.math.multiply_18[0][0]']
#
#  add_metric (AddMetric)         ()                   0           ['tf.math.multiply_18[0][0]']
#
#  tf.concat_4 (TFOpLambda)       (None, 1600)         0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]']
#
#  tf.concat_3 (TFOpLambda)       (None, 1600)         0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]']
#
#  tf.cast_11 (TFOpLambda)        (None, 1600)         0           ['tf.concat_4[0][0]']
#
#  tf.cast_10 (TFOpLambda)        (None, 1600)         0           ['tf.concat_3[0][0]']
#
#  tf.math.subtract_5 (TFOpLambda  (None, 1600)        0           ['tf.cast_11[0][0]',
#  )                                                                'tf.cast_10[0][0]']
#
#  Beta_Feat (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.square_1 (TFOpLambda)  (None, 1600)         0           ['tf.math.subtract_5[0][0]']
#
#  tf.cast_7 (TFOpLambda)         ()                   0           ['Beta_Feat[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  ()                  0           ['tf.math.square_1[0][0]']
#  bda)
#
#  tf.math.multiply_19 (TFOpLambd  ()                  0           ['tf.cast_7[0][0]',
#  a)                                                               'tf.math.reduce_mean_1[0][0]']
#
#  add_loss_1 (AddLoss)           ()                   0           ['tf.math.multiply_19[0][0]']
#
#  add_metric_1 (AddMetric)       ()                   0           ['tf.math.multiply_19[0][0]']
#
#  tf.math.pow (TFOpLambda)       (None, 30)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_3 (TFOpLambda)     (None, 30)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 30)          0           ['tf.math.pow[0][0]',
#  ambda)                                                           'tf.math.exp_3[0][0]']
#
#  tf.math.subtract_14 (TFOpLambd  (None, 30)          0           ['tf.__operators__.add_11[0][0]',
#  a)                                                               'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_15 (TFOpLambd  (None, 30)          0           ['tf.math.subtract_14[0][0]']
#  a)
#
#  tf.math.reduce_sum_7 (TFOpLamb  (None,)             0           ['tf.math.subtract_15[0][0]']
#  da)
#
#  tf.math.multiply_28 (TFOpLambd  (None,)             0           ['tf.math.reduce_sum_7[0][0]']
#  a)
#
#  Beta_Z (Lossweight)            ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_5 (TFOpLam  ()                  0           ['tf.math.multiply_28[0][0]']
#  bda)
#
#  tf.cast_2 (TFOpLambda)         ()                   0           ['Beta_Z[0][0]']
#
#  tf.math.subtract_16 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_5[0][0]']
#  a)
#
#  tf.cast_19 (TFOpLambda)        ()                   0           ['tf.cast_2[0][0]']
#
#  tf.math.abs (TFOpLambda)       ()                   0           ['tf.math.subtract_16[0][0]']
#
#  tf.math.multiply_29 (TFOpLambd  ()                  0           ['tf.cast_19[0][0]',
#  a)                                                               'tf.math.abs[0][0]']
#
#  add_loss_2 (AddLoss)           ()                   0           ['tf.math.multiply_29[0][0]']
#
#  add_metric_2 (AddMetric)       ()                   0           ['tf.math.multiply_29[0][0]']
#
#  tf.cast_18 (TFOpLambda)        (None, 2)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_12 (TFOpLambd  (None, 2)           0           ['tf.cast_18[0][0]']
#  a)
#
#  tf.math.log_4 (TFOpLambda)     (None, 2)            0           ['tf.cast_18[0][0]']
#
#  tf.math.log_5 (TFOpLambda)     (None, 2)            0           ['tf.math.subtract_12[0][0]']
#
#  tf.math.subtract_10 (TFOpLambd  (None, 2)           0           ['tf.math.log_4[0][0]']
#  a)
#
#  tf.math.subtract_11 (TFOpLambd  (None, 2)           0           ['tf.cast_18[0][0]']
#  a)
#
#  tf.math.subtract_13 (TFOpLambd  (None, 2)           0           ['tf.math.log_5[0][0]']
#  a)
#
#  tf.math.multiply_26 (TFOpLambd  (None, 2)           0           ['tf.cast_18[0][0]',
#  a)                                                               'tf.math.subtract_10[0][0]']
#
#  tf.math.multiply_27 (TFOpLambd  (None, 2)           0           ['tf.math.subtract_11[0][0]',
#  a)                                                               'tf.math.subtract_13[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 2)           0           ['tf.math.multiply_26[0][0]',
#  ambda)                                                           'tf.math.multiply_27[0][0]']
#
#  tf.math.reduce_mean_4 (TFOpLam  ()                  0           ['tf.__operators__.add_10[0][0]']
#  bda)
#
#  Beta_Fc (Lossweight)           ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.subtract_17 (TFOpLambd  ()                  0           ['tf.math.reduce_mean_4[0][0]']
#  a)
#
#  tf.cast_3 (TFOpLambda)         ()                   0           ['Beta_Fc[0][0]']
#
#  tf.math.abs_1 (TFOpLambda)     ()                   0           ['tf.math.subtract_17[0][0]']
#
#  tf.math.multiply_30 (TFOpLambd  ()                  0           ['tf.cast_3[0][0]',
#  a)                                                               'tf.math.abs_1[0][0]']
#
#  add_loss_3 (AddLoss)           ()                   0           ['tf.math.multiply_30[0][0]']
#
#  add_metric_3 (AddMetric)       ()                   0           ['tf.math.multiply_30[0][0]']
#
# ==================================================================================================
# Total params: 234,892
# Trainable params: 234,888
# Non-trainable params: 4
# __________________________________________________________________________________________________
# Model weights loaded
# 10/10 [==============================] - 36s 33ms/step
# 10/10 [==============================] - 5s 41ms/step
# 10/10 [==============================] - 0s 31ms/step
# 10/10 [==============================] - 0s 32ms/step
# 10/10 [==============================] - 0s 31ms/step
# 10/10 [==============================] - 0s 31ms/step
# VDWave_ART_VitalDB ./Benchmarks/Config/EvalConfigART_Other.yml
# Model weights loaded
# 0 [ 0  6  7  8  9 10 11 12]
# [Restoration] Processing Steps:   3%|▉                                  | 1/36 [00:05<03:00,  5.16s/it, Current Step=1]
# Time elapsed: 5.15532112121582
# [Restoration] Processing Steps:   6%|█▉                                 | 2/36 [00:08<02:28,  4.35s/it, Current Step=3]
# Time elapsed: 3.782926321029663
# [Restoration] Processing Steps:   8%|██▉                                | 3/36 [00:12<02:15,  4.10s/it, Current Step=5]
# Time elapsed: 3.784743309020996
# [Restoration] Processing Steps:  11%|███▉                               | 4/36 [00:16<02:07,  3.98s/it, Current Step=7]
# Time elapsed: 3.784330368041992
# [Restoration] Processing Steps:  14%|████▊                              | 5/36 [00:20<02:01,  3.91s/it, Current Step=9]
# Time elapsed: 3.786722421646118
# [Restoration] Processing Steps:  17%|█████▋                            | 6/36 [00:24<01:56,  3.87s/it, Current Step=11]
# Time elapsed: 3.786311626434326
# [Restoration] Processing Steps:  19%|██████▌                           | 7/36 [00:27<01:51,  3.84s/it, Current Step=13]
# Time elapsed: 3.7876627445220947
# [Restoration] Processing Steps:  22%|███████▌                          | 8/36 [00:31<01:47,  3.83s/it, Current Step=15]
# Time elapsed: 3.791475296020508
# [Restoration] Processing Steps:  25%|████████▌                         | 9/36 [00:35<01:43,  3.82s/it, Current Step=17]
# Time elapsed: 3.7843546867370605
# [Restoration] Processing Steps:  28%|█████████▏                       | 10/36 [00:39<01:39,  3.81s/it, Current Step=19]
# [Restoration] Processing Steps:  17%|█████▋                            | 6/36 [00:22<01:53,  3.79s/it, Current Step=11]
# Time elapsed: 3.790907144546509
# [Restoration] Processing Steps:  19%|██████▌                           | 7/36 [00:26<01:50,  3.80s/it, Current Step=13]
# Time elapsed: 3.7951014041900635
# [Restoration] Processing Steps:  22%|███████▌                          | 8/36 [00:30<01:46,  3.80s/it, Current Step=15]
# Time elapsed: 3.790947675704956
# [Restoration] Processing Steps:  25%|████████▌                         | 9/36 [00:34<01:42,  3.80s/it, Current Step=17]
# Time elapsed: 3.792282819747925
# [Restoration] Processing Steps:  28%|█████████▏                       | 10/36 [00:37<01:38,  3.80s/it, Current Step=19]
# Time elapsed: 3.7906181812286377
# [Restoration] Processing Steps:  31%|██████████                       | 11/36 [00:41<01:34,  3.79s/it, Current Step=21]
# Time elapsed: 3.7884297370910645
# [Restoration] Processing Steps:  33%|███████████                      | 12/36 [00:45<01:31,  3.80s/it, Current Step=23]
# Time elapsed: 3.7951059341430664
# [Restoration] Processing Steps:  36%|███████████▉                     | 13/36 [00:49<01:27,  3.80s/it, Current Step=25]
# Time elapsed: 3.7930545806884766
# [Restoration] Processing Steps:  39%|████████████▊                    | 14/36 [00:53<01:23,  3.80s/it, Current Step=27]
# Time elapsed: 3.793720245361328
# [Restoration] Processing Steps:  42%|█████████████▊                   | 15/36 [00:56<01:19,  3.80s/it, Current Step=29]
# Time elapsed: 3.7916455268859863
# [Restoration] Processing Steps:  44%|██████████████▋                  | 16/36 [01:00<01:15,  3.80s/it, Current Step=31]
# Time elapsed: 3.7909936904907227
# [Restoration] Processing Steps:  47%|███████████████▌                 | 17/36 [01:04<01:12,  3.80s/it, Current Step=33]
# Time elapsed: 3.7894046306610107
# [Restoration] Processing Steps:  50%|████████████████▌                | 18/36 [01:08<01:08,  3.79s/it, Current Step=35]
# Time elapsed: 3.775334119796753
# [Restoration] Processing Steps:  53%|█████████████████▍               | 19/36 [01:12<01:04,  3.79s/it, Current Step=37]
# Time elapsed: 3.7733144760131836
# [Restoration] Processing Steps:  56%|██████████████████▎              | 20/36 [01:15<01:00,  3.78s/it, Current Step=39]
# Time elapsed: 3.773179292678833
# [Restoration] Processing Steps:  58%|███████████████████▎             | 21/36 [01:19<00:56,  3.78s/it, Current Step=41]
# Time elapsed: 3.775083065032959
# ...
#  tf.math.exp_36 (TFOpLambda)    (None, 30)           0           ['tf.math.multiply_179[0][0]']
#
#  tf.math.multiply_178 (TFOpLamb  (None, 30)          0           ['tf.random.normal_15[0][0]']
#  da)
#
#  tf.math.multiply_180 (TFOpLamb  (None, 30)          0           ['tf.math.exp_36[0][0]',
#  da)                                                              'tf.math.multiply_178[0][0]']
#
#  tf.__operators__.add_77 (TFOpL  (None, 30)          0           ['Z_Mu3[0][0]',
#  ambda)                                                           'tf.math.multiply_180[0][0]']
#
#  Zs2 (Lambda)                   (None, 30)           0           ['tf.__operators__.add_77[0][0]']
#
#  tf.concat_26 (TFOpLambda)      (None, 90)           0           ['Zs0[0][0]',
#                                                                   'Zs1[0][0]',
#                                                                   'Zs2[0][0]']
#
#  ReconModel (Functional)        (None, 1000)         132530      ['tf.concat_26[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  tf.cast_95 (TFOpLambda)        (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_94 (TFOpLambda)        (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_102 (TFOpLamb  (None, 1000)        0           ['tf.cast_95[0][0]',
#  da)                                                              'tf.cast_94[0][0]']
#
#  Beta_Rec (Lossweight)          ()                   1           ['Inp_Enc[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  tf.math.square_11 (TFOpLambda)  (None, 1000)        0           ['tf.math.subtract_102[0][0]']
#
#  tf.cast_93 (TFOpLambda)        ()                   0           ['Beta_Rec[0][0]']
#
#  tf.math.reduce_mean_39 (TFOpLa  ()                  0           ['tf.math.square_11[0][0]']
#  mbda)
#
#  tf.math.multiply_181 (TFOpLamb  ()                  0           ['tf.cast_93[0][0]',
#  da)                                                              'tf.math.reduce_mean_39[0][0]']
#
#  add_loss_22 (AddLoss)          ()                   0           ['tf.math.multiply_181[0][0]']
#
#  add_metric_22 (AddMetric)      ()                   0           ['tf.math.multiply_181[0][0]']
#
#  tf.math.pow_13 (TFOpLambda)    (None, 30)           0           ['Z_Mu1[0][0]']
#
#  tf.math.exp_37 (TFOpLambda)    (None, 30)           0           ['Z_Log_Sigma1[0][0]']
#
#  tf.__operators__.add_78 (TFOpL  (None, 30)          0           ['tf.math.pow_13[0][0]',
#  ambda)                                                           'tf.math.exp_37[0][0]']
#
#  tf.math.pow_14 (TFOpLambda)    (None, 30)           0           ['Z_Mu2[0][0]']
#
#  tf.math.exp_38 (TFOpLambda)    (None, 30)           0           ['Z_Log_Sigma2[0][0]']
#
#  tf.math.subtract_103 (TFOpLamb  (None, 30)          0           ['tf.__operators__.add_78[0][0]',
#  da)                                                              'Z_Log_Sigma1[0][0]']
#
#  tf.__operators__.add_80 (TFOpL  (None, 30)          0           ['tf.math.pow_14[0][0]',
#  ambda)                                                           'tf.math.exp_38[0][0]']
#
#  tf.math.pow_15 (TFOpLambda)    (None, 30)           0           ['Z_Mu3[0][0]']
#
#  tf.math.exp_39 (TFOpLambda)    (None, 30)           0           ['Z_Log_Sigma3[0][0]']
#
#  tf.math.subtract_104 (TFOpLamb  (None, 30)          0           ['tf.math.subtract_103[0][0]']
#  da)
#
#  tf.math.subtract_106 (TFOpLamb  (None, 30)          0           ['tf.__operators__.add_80[0][0]',
#  da)                                                              'Z_Log_Sigma2[0][0]']
#
#  tf.__operators__.add_82 (TFOpL  (None, 30)          0           ['tf.math.pow_15[0][0]',
#  ambda)                                                           'tf.math.exp_39[0][0]']
#
#  tf.math.reduce_sum_41 (TFOpLam  (None,)             0           ['tf.math.subtract_104[0][0]']
#  bda)
#
#  tf.math.subtract_107 (TFOpLamb  (None, 30)          0           ['tf.math.subtract_106[0][0]']
#  da)
#
#  tf.math.subtract_109 (TFOpLamb  (None, 30)          0           ['tf.__operators__.add_82[0][0]',
#  da)                                                              'Z_Log_Sigma3[0][0]']
#
#  tf.math.multiply_182 (TFOpLamb  (None,)             0           ['tf.math.reduce_sum_41[0][0]']
#  da)
#
#  tf.math.reduce_sum_42 (TFOpLam  (None,)             0           ['tf.math.subtract_107[0][0]']
#  bda)
#
#  tf.math.subtract_110 (TFOpLamb  (None, 30)          0           ['tf.math.subtract_109[0][0]']
#  da)
#
#  tf.math.reduce_mean_40 (TFOpLa  ()                  0           ['tf.math.multiply_182[0][0]']
#  mbda)
#
#  tf.math.multiply_184 (TFOpLamb  (None,)             0           ['tf.math.reduce_sum_42[0][0]']
#  da)
#
#  tf.math.reduce_sum_43 (TFOpLam  (None,)             0           ['tf.math.subtract_110[0][0]']
#  bda)
#
#  Beta_Z (Lossweight)            ()                   1           ['Inp_Enc[0][0]',
#                                                                   'Inp_Cond[0][0]']
#
#  tf.math.subtract_105 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_40[0][0]']
#  da)
#
#  tf.math.reduce_mean_41 (TFOpLa  ()                  0           ['tf.math.multiply_184[0][0]']
#  mbda)
#
#  tf.math.multiply_186 (TFOpLamb  (None,)             0           ['tf.math.reduce_sum_43[0][0]']
#  da)
#
#  tf.cast_92 (TFOpLambda)        ()                   0           ['Beta_Z[0][0]']
#
#  tf.math.abs_17 (TFOpLambda)    ()                   0           ['tf.math.subtract_105[0][0]']
#
#  tf.math.subtract_108 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_41[0][0]']
#  da)
#
#  tf.math.reduce_mean_42 (TFOpLa  ()                  0           ['tf.math.multiply_186[0][0]']
#  mbda)
#
#  tf.math.multiply_183 (TFOpLamb  ()                  0           ['tf.cast_92[0][0]',
#  da)                                                              'tf.math.abs_17[0][0]']
#
#  tf.math.abs_18 (TFOpLambda)    ()                   0           ['tf.math.subtract_108[0][0]']
#
#  tf.math.subtract_111 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_42[0][0]']
#  da)
#
#  tf.__operators__.add_79 (TFOpL  ()                  0           ['tf.math.multiply_183[0][0]']
#  ambda)
#
#  tf.math.multiply_185 (TFOpLamb  ()                  0           ['tf.cast_92[0][0]',
#  da)                                                              'tf.math.abs_18[0][0]']
#
#  tf.math.abs_19 (TFOpLambda)    ()                   0           ['tf.math.subtract_111[0][0]']
#
#  tf.__operators__.add_81 (TFOpL  ()                  0           ['tf.__operators__.add_79[0][0]',
#  ambda)                                                           'tf.math.multiply_185[0][0]']
#
#  tf.math.multiply_187 (TFOpLamb  ()                  0           ['tf.cast_92[0][0]',
#  da)                                                              'tf.math.abs_19[0][0]']
#
#  tf.__operators__.add_83 (TFOpL  ()                  0           ['tf.__operators__.add_81[0][0]',
#  ambda)                                                           'tf.math.multiply_187[0][0]']
#
#  tf.math.reduce_mean_43 (TFOpLa  ()                  0           ['tf.__operators__.add_83[0][0]']
#  mbda)
#
#  add_loss_23 (AddLoss)          ()                   0           ['tf.math.reduce_mean_43[0][0]']
#
#  add_metric_23 (AddMetric)      ()                   0           ['tf.__operators__.add_83[0][0]']
#
# ==================================================================================================
# Total params: 361,772
# Trainable params: 361,170
# Non-trainable params: 602
# __________________________________________________________________________________________________
# Model weights loaded
# 10/10 [==============================] - 4s 40ms/step
# 10/10 [==============================] - 4s 43ms/step
# 10/10 [==============================] - 0s 26ms/step
# 10/10 [==============================] - 0s 26ms/step
# 10/10 [==============================] - 0s 25ms/step
# 10/10 [==============================] - 0s 25ms/step

# %% [markdown]
# ## Multi-Panel Visualization of Cross-Dataset Signal Generation and PSD Comparisons

# %%
# --- Data loading and basic setup ---
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from matplotlib.patches import Rectangle
import numpy as np
import pickle
from matplotlib.gridspec import GridSpec

with open("./EvalResults/Instances/DicPList.pkl", "rb") as f:
    DicPList = pickle.load(f)
with open("./EvalResults/Instances/DicQ.pkl", "rb") as f:
    DicQ = pickle.load(f)

FONT_SIZE = 13      # Font size for axis labels and tick labels
TITLE_SIZE = 15     # Font size for subplot titles
LEGEND_SIZE = 13    # Font size for legend text
YTICK_SIZE = 13     # Font size for y-tick labels (if shown)
HIDE_YTICKS = True  # Whether to hide y-axis ticks and labels
HSPACE = 0.4        # Vertical space between subplots
WSPACE = 0.3        # Horizontal space between subplots

up_keys = ['ART_VitalDB', 'ART_Mimic', 'II_VitalDB', 'II_Mimic']

def get_model_label(dn_key):
    if 'SKZFC' in dn_key:
        return 'VABAM'
    elif 'VDWave' in dn_key:
        return 'VDWave'
    elif 'TCVAE' in dn_key:
        return 'TC-VAE'
    elif 'VDVAE' in dn_key:
        return 'VD-VAE'
    else:
        return dn_key  # Fallback: use original key

# --- (1) Collect all (up_key, dn_key) pairs grouped by source ---
groups = {'VitalDB': [], 'Mimic': []}
for up_key in up_keys:
    *_, data_source = up_key.split('_')
    for dn_key in DicPList[up_key]:
        groups[data_source].append((up_key, dn_key))

# --- (2) Create ONE combined figure using GridSpec ---
# Panel order: 'Mimic to VitalDB' (left), 'VitalDB to Mimic' (right)
# A spacer column (index 3) provides the visual gap between the two panels
source_order = ['Mimic', 'VitalDB']

fig = plt.figure(figsize=(16, 5))

# GridSpec: 2 rows x 7 cols  [left-panel: 0-2 | spacer: 3 | right-panel: 4-6]
# top/bottom leave room for the gray-bar labels above the subplots
gs = GridSpec(
    2, 7,
    figure=fig,
    hspace=HSPACE,
    wspace=WSPACE,
    left=0.05, right=0.98,
    top=0.8,             # leave space at top for the bar labels
    bottom=0.10,
    width_ratios=[1, 1, 1, -0.2, 1, 1, 1]  # spacer col is 0.5x width
)

# Column indices for each panel in the GridSpec
left_cols  = [0, 1, 2]   # Mimic to VitalDB
right_cols = [4, 5, 6]   # VitalDB to Mimic
col_groups = [left_cols, right_cols]

# Store axes per panel to compute label positions later
all_axes = {source: [] for source in source_order}

for panel_idx, (source, cols) in enumerate(zip(source_order, col_groups)):
    chunk = groups[source]

    for i, (up_key, dn_key) in enumerate(chunk):
        row, col_in_panel = divmod(i, 3)
        col_idx = cols[col_in_panel]
        ax = fig.add_subplot(gs[row, col_idx])
        all_axes[source].append(ax)

        signal_type, *_ = up_key.split('_')
        signal_type = 'ABP' if signal_type == 'ART' else 'ECG' if signal_type == 'II' else signal_type

        # Plot generated signals (dashed lines)
        for vec in DicPList[up_key][dn_key]:
            ax.plot(np.squeeze(vec), linestyle='--', linewidth=1.5, alpha=0.7)

        # Plot the reference signal (solid black line)
        original_handle, = ax.plot(
            DicQ[up_key][dn_key],
            color='black',
            linewidth=2.,
            label='Original',
            alpha=0.7
        )

        # Dummy line for the model legend with thicker linewidth
        model_label = get_model_label(dn_key)
        dummy_line = mlines.Line2D(
            [], [], color='gray', linestyle='--',
            linewidth=3., label=model_label
        )

        # Title and axis labels
        ax.set_title(f"{signal_type}", fontsize=TITLE_SIZE)
        if row == 1:
            ax.set_xlabel("Frequency (Hz)", fontsize=FONT_SIZE)
        if col_in_panel == 0:          # leftmost column of each panel
            ax.set_ylabel("PSD", fontsize=FONT_SIZE)

        # Y-axis ticks
        if HIDE_YTICKS:
            ax.set_yticks([])
            ax.set_yticklabels([])
        else:
            ax.tick_params(axis='y', labelsize=YTICK_SIZE)
        ax.tick_params(axis='x', labelsize=FONT_SIZE - 2)

        # Legend
        ax.legend(handles=[dummy_line, original_handle], fontsize=LEGEND_SIZE)

# --- (3) Add gray bar + label above each panel ---
# Force a draw so axes positions are finalised before reading them
fig.canvas.draw()

for source in source_order:
    panel_axes = all_axes[source]

    # All positions are in figure-level normalised coordinates (0-1)
    bboxes     = [ax.get_position() for ax in panel_axes]
    left_edge  = min(bb.x0 for bb in bboxes)
    right_edge = max(bb.x1 for bb in bboxes)
    top_edge   = max(bb.y1 for bb in bboxes)

    bar_height = 0.025          # height of the gray rectangle
    gap        = 0.06          # clear gap between subplot top and bar bottom
    bar_bottom = top_edge + gap

    # Add gray background rectangle (clip_on=False so it is never clipped)
    rect = Rectangle(
        (left_edge, bar_bottom),
        right_edge - left_edge,
        bar_height,
        transform=fig.transFigure,
        facecolor="#cfcfcf",
        alpha=0.4,
        zorder=2,
        clip_on=False
    )
    fig.add_artist(rect)

    anno = 'Mimic to VitalDB' if source == 'Mimic' else 'VitalDB to Mimic'

    # Text sits just above the bar, centred over the panel
    fig.text(
        (left_edge + right_edge) / 2,
        bar_bottom + bar_height + 0.01,
        anno,
        ha='center',
        va='bottom',
        fontsize=15,
        transform=fig.transFigure
    )

# ── Panel labels b, c ─────────────────────────────────────────────────────────
for label, source in zip(['b', 'c'], source_order):
    first_ax = all_axes[source][0]   # first axes of each section
    pos = first_ax.get_position()

    fig.text(
        pos.x0 - 0.015,              # slightly outside the left edge of axes
        pos.y1 + 0.065,              # just below the gray bar (gap=0.06)
        label,
        ha='left',
        va='bottom',
        fontsize=17,                # effective 6.6pt ✅
        transform=fig.transFigure,
        clip_on=False
    )


# --- Save combined figure to a single file ---
target_w_inch = 180 / 12.   # 7.087 inch

current_w, current_h = fig.get_size_inches()
scale_factor = target_w_inch / current_w
target_h_inch = current_h * scale_factor

fig.set_size_inches(target_w_inch, target_h_inch)


filename = "GenDist Mimic_VitalDB Combined.pdf"
fig.savefig('./PaperWork/Figures/' + filename, bbox_inches='tight')
print(f"Saved {filename}")

# Display inline in the notebook
plt.show()
plt.close(fig)
# Out:
# Saved GenDist Mimic_VitalDB Combined.pdf
