# %%
import re
import os
import pandas as pd
import numpy as np
import tensorflow as tf
tf.config.set_visible_devices([], 'GPU')

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as patches

import matplotlib as mpl
from matplotlib.patches import Rectangle
from matplotlib import ticker, transforms
from collections import OrderedDict

from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import FuncFormatter

from Utilities.Utilities import ReadYaml, SerializeObjects, DeserializeObjects, LoadModelConfigs, LoadParams

from Utilities.Visualization import VisReconGivenZ_FCA, HeatMapFreqZ_FCA, VisReconGivenFC_ZA, VisReconExtractZ_FC
from Utilities.AncillaryFunctions import compute_snr, GenConArangeSimple, scale_and_normalize

from Models.Caller import *
from Benchmarks.Models.BenchmarkCaller import ModelCall as BMCaller

from Benchmarks.Models.DiffWave import DiffWAVE_Restoration, determine_gen_steps_diffwave
from Benchmarks.Models.VDiffWave import VDiffWAVE_Restoration, determine_gen_steps_vdwave

# %% [markdown]
# ### Signal Generation and Evaluation Functions

# %%
def CustomLinspace(start, end, breakpoints, numbers):
    """
    Generate a series of points within specified intervals and number of points.

    Parameters:
    start (float): The starting value of the sequence.
    end (float): The end value of the sequence.
    breakpoints (list): A list of points where the intervals change.
    numbers (list): A list of integers indicating the number of points in each interval.

    Returns:
    np.array: An array of points including the start, end, and the specified number of points in each interval.
    """

    # Validate input: there should be one more number than there are breakpoints
    if len(breakpoints) + 1 != len(numbers):
        raise ValueError("There must be one more element in 'numbers' than there are in 'breakpoints'.")

    # Combine the start, breakpoints, and end into a single list of points
    points = [start] + breakpoints + [end]
    
    # Initialize an empty array to hold the result
    result = np.array([])

    # Generate points for each interval
    for i in range(len(numbers)):
        # Determine if the endpoint should be included
        endpoint = True if i == len(numbers) - 1 else False  # Include endpoint only for the last interval
        
        # Generate 'numbers[i]' points between 'points[i]' and 'points[i + 1]'
        part = np.linspace(points[i], points[i + 1], numbers[i], endpoint=endpoint)
        result = np.concatenate((result, part))  # Append the new points to the result

    return result


def SigGen(ConfigName, YamlPath, SelIDX=1, N_Gen=300, MinFreqR=0.0, MaxFreqR=0.05, GenBP=None, N_GenList=None):
    
    if N_GenList is not None:
        N_Gen = np.sum(N_GenList)
    
    EvalConfigs = ReadYaml(YamlPath)
    
    # Loading the model configurations
    ModelConfigSet, ModelLoadName = LoadModelConfigs(ConfigName)
    
    # Loading parameters for the evaluation
    Params = LoadParams(ModelConfigSet, EvalConfigs['Parameters'])
    Params['Common_Info'] = EvalConfigs['Common_Info']
    
    # Loading data
    VallData = np.load('./Data/Demo/'+'Demo_'+str(Params['TestDataSource'])+str(Params['SigType'])+'.npy').astype('float32')

    # Intermediate parameters 
    SigDim = VallData.shape[1]
    DataSize = VallData.shape[0]
    Params['DataSize'] = Params['EvalDataSize']

    # Calling Models
    SigRepModel, ModelParts = ModelCall(ModelConfigSet, SigDim, DataSize, LoadWeight=True, ReturnModelPart=True, Reparam=False, ReparaStd=Params['ReparaStd'], ModelSaveName=ModelLoadName)
    
    # Setting Model Specifications and Sub-models
    if Params['LossType'] == 'Default':
        EncModel, FeatExtModel, FeatGenModel, ReconModel = ModelParts
    elif Params['LossType'] == 'FACLosses':
        EncModel, FeatExtModel, FeatGenModel, ReconModel, FacDiscModel = ModelParts

    NeachFC = len(FeatExtModel.output)
    NCommonFC = EncModel.output[1].shape[1] - NeachFC

    if N_GenList is not None:
        FC_Each = np.tile(CustomLinspace(MinFreqR, MaxFreqR, GenBP, N_GenList)[:, None], (1, NeachFC))
        if NCommonFC == 0:
            FC_Comm = np.empty((FC_Each.shape[0], 0))
        else:
            FC_Comm = np.tile(CustomLinspace(MinFreqR, MaxFreqR, GenBP, N_GenList)[:, None], (1, NCommonFC))    
    else:
        FC_Each = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen)[:, None], (1, NeachFC))
        if NCommonFC == 0:
            FC_Comm = np.empty((FC_Each.shape[0], 0))
        else:
            FC_Comm = np.tile(np.linspace(MinFreqR, MaxFreqR, N_Gen)[:, None], (1, NCommonFC))

    ## The generation model for evaluation
    RecOut = ReconModel(FeatGenModel.output)
    GenModel = Model(FeatGenModel.input, RecOut)
    
    ## The sampling model for evaluation
    Zs_Out = SigRepModel.get_layer('Zs').output
    SampModel = Model(EncModel.input, Zs_Out)

    # Signal generation
    AnalData = VallData
    OrginalSig = AnalData[SelIDX:SelIDX+1]
    InpSignal = np.repeat(OrginalSig, N_Gen, axis=0)
    PredZs = SampModel.predict(InpSignal)

    FeatGen = FeatGenModel([FC_Comm, FC_Each, PredZs])
    ReconSignal = ReconModel.predict([FeatGen])
    CON_Arange = None

    HalfLen = ReconSignal.shape[1]//2
    FFTRes = np.abs(np.fft.fft(ReconSignal, axis=-1)[:, :HalfLen]) 
    Amplitude = FFTRes/HalfLen

    return ReconSignal, Amplitude, OrginalSig, PredZs, CON_Arange

# %% [markdown]
# ### Batch Evaluation Setup and Execution

# %%
DicConfigYaml = { 
    'ART_VitalDB': {'SKZFC_ART_2_30_800_VitalDB': './Config/EvalConfigVitalDB.yml'},
    'ART_Mimic': {'SKZFC_ART_2_30_800_Mimic': './Config/EvalConfigMimic.yml'},
    'II_VitalDB': {'SKZFC_II_1_30_800_VitalDB': './Config/EvalConfigVitalDB.yml'},
    'II_Mimic': {'SKZFC_II_1_30_800_Mimic': './Config/EvalConfigMimic.yml'}
}

MinFreq = 1
MaxFreq = 50

DicParam = {
    'ART_VitalDB': {
        'SelIDX': 7, 
        'MinFreqR': 0.000, 
        'MaxFreqR': 0.9, 
        'GenBP': [0.03, 0.1],
        'N_GenList': [500, 50, 50]
    },
    'ART_Mimic': {
        'SelIDX': 20, 
        'MinFreqR': 0.000, 
        'MaxFreqR': 0.9, 
        'GenBP': [0.004, 0.05], 
        'N_GenList': [300, 200, 100]
    },
    'II_VitalDB': {
        'SelIDX': 5, 
        'MinFreqR': 0.01, 
        'MaxFreqR': 0.9, 
        'GenBP': [0.05, 0.2], 
        'N_GenList': [400, 0, 200]
    },
    'II_Mimic': {
        'SelIDX': 1, 
        'MinFreqR': 0.001, 
        'MaxFreqR': 0.9, 
        'GenBP': [0.05, 0.1], 
        'N_GenList': [400, 0, 200]
    }
}

GeneratedSignals = {}
GeneratedAmplitude = {}
InpSignals = {}
Zs = {}
CON_Aranges = {}

for ConfigYaml in DicConfigYaml.items():
    SelIDX, MinFreqR, MaxFreqR, GenBP, N_GenList = DicParam[ConfigYaml[0]].values()
    for ConfigName in ConfigYaml[1]:
        print(ConfigName)
        ReconSignal, Amplitude, InpSignal, PredZs, CON_Arange = SigGen(
            ConfigName, ConfigYaml[1][ConfigName], 
            SelIDX=SelIDX, 
            N_Gen=np.sum(N_GenList), 
            MinFreqR=MinFreqR, 
            MaxFreqR=MaxFreqR,  
            GenBP=GenBP, 
            N_GenList=N_GenList
        )
        GeneratedSignals[ConfigName] = ReconSignal
        GeneratedAmplitude[ConfigName] = Amplitude
        InpSignals[ConfigName] = InpSignal
        Zs[ConfigName] = PredZs
        CON_Aranges[ConfigName] = CON_Arange
# Out:
# SKZFC_ART_2_30_800_VitalDB
# OrigRecLoss added
# FeatRecLoss added
# kl_Loss_SKZ selected
# kl_Loss_Z added
# kl_Loss_FC added
# Model: "model_42"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame_50 (TFOpLambda  (None, 20, 50)      0           ['Inp_Enc[0][0]']
#  )
#
#  bidirectional_212 (Bidirection  (None, 20, 50)      11550       ['tf.signal.frame_50[0][0]']
#  al)
#
#  bidirectional_213 (Bidirection  (None, 20, 50)      11550       ['bidirectional_212[0][0]']
#  al)
#
#  bidirectional_214 (Bidirection  (None, 150)         57150       ['bidirectional_213[0][0]']
#  al)
#
#  dense_314 (Dense)              (None, 100)          15100       ['bidirectional_214[0][0]']
#
#  dense_315 (Dense)              (None, 70)           7070        ['dense_314[0][0]']
#
#  dense_316 (Dense)              (None, 50)           3550        ['dense_315[0][0]']
#
#  dense_318 (Dense)              (None, 6)            306         ['dense_316[0][0]']
#
#  dense_319 (Dense)              (None, 6)            42          ['dense_318[0][0]']
#
#  tf.clip_by_value_42 (TFOpLambd  (None, 6)           0           ['dense_319[0][0]']
#  a)
#
#  FC_Mu (Lambda)                 (None, 6)            0           ['tf.clip_by_value_42[0][0]']
#
#  tf.compat.v1.shape_29 (TFOpLam  (2,)                0           ['FC_Mu[0][0]']
#  bda)
#
#  tf.__operators__.getitem_273 (  ()                  0           ['tf.compat.v1.shape_29[0][0]']
#  SlicingOpLambda)
#
#  tf.random.uniform_14 (TFOpLamb  (None, 6)           0           ['tf.__operators__.getitem_273[0]
#  da)                                                             [0]']
#
#  tf.clip_by_value_43 (TFOpLambd  (None, 6)           0           ['tf.random.uniform_14[0][0]']
#  a)
#
#  tf.math.subtract_252 (TFOpLamb  (None, 6)           0           ['tf.clip_by_value_43[0][0]']
#  da)
#
#  tf.math.log_84 (TFOpLambda)    (None, 6)            0           ['tf.clip_by_value_43[0][0]']
#
#  tf.math.log_85 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_252[0][0]']
#
#  tf.math.subtract_254 (TFOpLamb  (None, 6)           0           ['tf.math.log_84[0][0]',
#  da)                                                              'tf.math.log_85[0][0]']
#
#  tf.math.log_86 (TFOpLambda)    (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_253 (TFOpLamb  (None, 6)           0           ['FC_Mu[0][0]']
#  da)
#
#  tf.__operators__.add_173 (TFOp  (None, 6)           0           ['tf.math.subtract_254[0][0]',
#  Lambda)                                                          'tf.math.log_86[0][0]']
#
#  tf.math.log_87 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_253[0][0]']
#
#  tf.math.subtract_255 (TFOpLamb  (None, 6)           0           ['tf.__operators__.add_173[0][0]'
#  da)                                                             , 'tf.math.log_87[0][0]']
#
#  Z_Mu (Dense)                   (None, 30)           1530        ['dense_316[0][0]']
#
#  tf.math.sigmoid_14 (TFOpLambda  (None, 6)           0           ['tf.math.subtract_255[0][0]']
#  )
#
#  dense_317 (Dense)              (None, 30)           1530        ['dense_316[0][0]']
#
#  tf.compat.v1.shape_28 (TFOpLam  (2,)                0           ['Z_Mu[0][0]']
#  bda)
#
#  tf.math.multiply_485 (TFOpLamb  (None, 6)           0           ['tf.math.sigmoid_14[0][0]']
#  da)
#
#  tf.math.multiply_486 (TFOpLamb  (None, 6)           0           ['FC_Mu[0][0]']
#  da)
#
#  Z_Log_Sigma (Lambda)           (None, 30)           0           ['dense_317[0][0]']
#
#  tf.__operators__.getitem_272 (  ()                  0           ['tf.compat.v1.shape_28[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.add_174 (TFOp  (None, 6)           0           ['tf.math.multiply_485[0][0]',
#  Lambda)                                                          'tf.math.multiply_486[0][0]']
#
#  tf.math.multiply_483 (TFOpLamb  (None, 30)          0           ['Z_Log_Sigma[0][0]']
#  da)
#
#  tf.random.normal_14 (TFOpLambd  (None, 30)          0           ['tf.__operators__.getitem_272[0]
#  a)                                                              [0]']
#
#  tf.math.multiply_487 (TFOpLamb  (None, 6)           0           ['tf.__operators__.add_174[0][0]'
#  da)                                                             ]
#
#  tf.math.exp_56 (TFOpLambda)    (None, 30)           0           ['tf.math.multiply_483[0][0]']
#
#  tf.math.multiply_482 (TFOpLamb  (None, 30)          0           ['tf.random.normal_14[0][0]']
#  da)
#
#  tf.clip_by_value_44 (TFOpLambd  (None, 6)           0           ['tf.math.multiply_487[0][0]']
#  a)
#
#  tf.math.multiply_484 (TFOpLamb  (None, 30)          0           ['tf.math.exp_56[0][0]',
#  da)                                                              'tf.math.multiply_482[0][0]']
#
#  FCs (Lambda)                   (None, 6)            0           ['tf.clip_by_value_44[0][0]']
#
#  tf.__operators__.add_172 (TFOp  (None, 30)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_484[0][0]']
#
#  tf.__operators__.getitem_301 (  (None, 2)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_302 (  (None, 4)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  Zs (Lambda)                    (None, 30)           0           ['tf.__operators__.add_172[0][0]'
#                                                                  ]
#
#  SigOut (Flatten)               (None, 1000)         0           ['tf.signal.frame_50[0][0]']
#
#  FeatGenModel (Functional)      [(None, 800),        82100       ['tf.__operators__.getitem_301[0]
#                                  (None, 800),                    [0]',
#                                  (None, 800),                     'tf.__operators__.getitem_302[0]
#                                  (None, 800)]                    [0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 800),        0           ['SigOut[0][0]',
#                                  (None, 800),                     'FCs[0][0]']
#                                  (None, 800),
#                                  (None, 800)]
#
#  ReconModel (Functional)        (None, 1000)         191300      ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_71 (TFOpLambda)        (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_70 (TFOpLambda)        (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_256 (TFOpLamb  (None, 1000)        0           ['tf.cast_71[0][0]',
#  da)                                                              'tf.cast_70[0][0]']
#
#  tf.math.square_28 (TFOpLambda)  (None, 1000)        0           ['tf.math.subtract_256[0][0]']
#
#  Beta_Orig (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_84 (TFOpLa  ()                  0           ['tf.math.square_28[0][0]']
#  mbda)
#
#  tf.math.multiply_524 (TFOpLamb  ()                  0           ['Beta_Orig[0][0]',
#  da)                                                              'tf.math.reduce_mean_84[0][0]']
#
#  add_loss_56 (AddLoss)          ()                   0           ['tf.math.multiply_524[0][0]']
#
#  add_metric_56 (AddMetric)      ()                   0           ['tf.math.multiply_524[0][0]']
#
#  tf.concat_83 (TFOpLambda)      (None, 3200)         0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]']
#
#  tf.concat_82 (TFOpLambda)      (None, 3200)         0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_73 (TFOpLambda)        (None, 3200)         0           ['tf.concat_83[0][0]']
#
#  tf.cast_72 (TFOpLambda)        (None, 3200)         0           ['tf.concat_82[0][0]']
#
#  tf.math.subtract_257 (TFOpLamb  (None, 3200)        0           ['tf.cast_73[0][0]',
#  da)                                                              'tf.cast_72[0][0]']
#
#  tf.math.square_29 (TFOpLambda)  (None, 3200)        0           ['tf.math.subtract_257[0][0]']
#
#  Beta_Feat (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_85 (TFOpLa  ()                  0           ['tf.math.square_29[0][0]']
#  mbda)
#
#  tf.math.multiply_525 (TFOpLamb  ()                  0           ['Beta_Feat[0][0]',
#  da)                                                              'tf.math.reduce_mean_85[0][0]']
#
#  add_loss_57 (AddLoss)          ()                   0           ['tf.math.multiply_525[0][0]']
#
#  add_metric_57 (AddMetric)      ()                   0           ['tf.math.multiply_525[0][0]']
#
#  tf.math.pow_14 (TFOpLambda)    (None, 30)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_59 (TFOpLambda)    (None, 30)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_185 (TFOp  (None, 30)          0           ['tf.math.pow_14[0][0]',
#  Lambda)                                                          'tf.math.exp_59[0][0]']
#
#  tf.math.subtract_266 (TFOpLamb  (None, 30)          0           ['tf.__operators__.add_185[0][0]'
#  da)                                                             , 'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_267 (TFOpLamb  (None, 30)          0           ['tf.math.subtract_266[0][0]']
#  da)
#
#  tf.math.reduce_sum_143 (TFOpLa  (None,)             0           ['tf.math.subtract_267[0][0]']
#  mbda)
#
#  tf.math.multiply_534 (TFOpLamb  (None,)             0           ['tf.math.reduce_sum_143[0][0]']
#  da)
#
#  tf.math.reduce_mean_89 (TFOpLa  ()                  0           ['tf.math.multiply_534[0][0]']
#  mbda)
#
#  tf.math.subtract_268 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_89[0][0]']
#  da)
#
#  Beta_Z (Lossweight)            ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_28 (TFOpLambda)    ()                   0           ['tf.math.subtract_268[0][0]']
#
#  tf.math.multiply_535 (TFOpLamb  ()                  0           ['Beta_Z[0][0]',
#  da)                                                              'tf.math.abs_28[0][0]']
#
#  add_loss_58 (AddLoss)          ()                   0           ['tf.math.multiply_535[0][0]']
#
#  add_metric_58 (AddMetric)      ()                   0           ['tf.math.multiply_535[0][0]']
#
#  tf.cast_74 (TFOpLambda)        (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_264 (TFOpLamb  (None, 6)           0           ['tf.cast_74[0][0]']
#  da)
#
#  tf.math.log_88 (TFOpLambda)    (None, 6)            0           ['tf.cast_74[0][0]']
#
#  tf.math.log_89 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_264[0][0]']
#
#  tf.math.subtract_262 (TFOpLamb  (None, 6)           0           ['tf.math.log_88[0][0]']
#  da)
#
#  tf.math.subtract_263 (TFOpLamb  (None, 6)           0           ['tf.cast_74[0][0]']
#  da)
#
#  tf.math.subtract_265 (TFOpLamb  (None, 6)           0           ['tf.math.log_89[0][0]']
#  da)
#
#  tf.math.multiply_532 (TFOpLamb  (None, 6)           0           ['tf.cast_74[0][0]',
#  da)                                                              'tf.math.subtract_262[0][0]']
#
#  tf.math.multiply_533 (TFOpLamb  (None, 6)           0           ['tf.math.subtract_263[0][0]',
#  da)                                                              'tf.math.subtract_265[0][0]']
#
#  tf.__operators__.add_184 (TFOp  (None, 6)           0           ['tf.math.multiply_532[0][0]',
#  Lambda)                                                          'tf.math.multiply_533[0][0]']
#
#  tf.math.reduce_mean_88 (TFOpLa  ()                  0           ['tf.__operators__.add_184[0][0]'
#  mbda)                                                           ]
#
#  tf.math.subtract_269 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_88[0][0]']
#  da)
#
#  Beta_Fc (Lossweight)           ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_29 (TFOpLambda)    ()                   0           ['tf.math.subtract_269[0][0]']
#
#  tf.math.multiply_536 (TFOpLamb  ()                  0           ['Beta_Fc[0][0]',
#  da)                                                              'tf.math.abs_29[0][0]']
#
#  add_loss_59 (AddLoss)          ()                   0           ['tf.math.multiply_536[0][0]']
#
#  add_metric_59 (AddMetric)      ()                   0           ['tf.math.multiply_536[0][0]']
#
# ==================================================================================================
# Total params: 382,782
# Trainable params: 382,778
# Non-trainable params: 4
# __________________________________________________________________________________________________
# Model weights loaded
# 19/19 [==============================] - 2s 11ms/step
# 19/19 [==============================] - 3s 8ms/step
# SKZFC_ART_2_30_800_Mimic
# OrigRecLoss added
# FeatRecLoss added
# kl_Loss_SKZ selected
# kl_Loss_Z added
# kl_Loss_FC added
# Model: "model_45"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Inp_Enc (InputLayer)           [(None, 1000)]       0           []
#
#  tf.signal.frame_57 (TFOpLambda  (None, 20, 50)      0           ['Inp_Enc[0][0]']
#  )
#
#  bidirectional_234 (Bidirection  (None, 20, 50)      11550       ['tf.signal.frame_57[0][0]']
#  al)
#
#  bidirectional_235 (Bidirection  (None, 20, 50)      11550       ['bidirectional_234[0][0]']
#  al)
#
#  bidirectional_236 (Bidirection  (None, 150)         57150       ['bidirectional_235[0][0]']
#  al)
#
#  dense_345 (Dense)              (None, 100)          15100       ['bidirectional_236[0][0]']
#
#  dense_346 (Dense)              (None, 70)           7070        ['dense_345[0][0]']
#
#  dense_347 (Dense)              (None, 50)           3550        ['dense_346[0][0]']
#
#  dense_349 (Dense)              (None, 6)            306         ['dense_347[0][0]']
#
#  dense_350 (Dense)              (None, 6)            42          ['dense_349[0][0]']
#
#  tf.clip_by_value_45 (TFOpLambd  (None, 6)           0           ['dense_350[0][0]']
#  a)
#
#  FC_Mu (Lambda)                 (None, 6)            0           ['tf.clip_by_value_45[0][0]']
#
#  tf.compat.v1.shape_31 (TFOpLam  (2,)                0           ['FC_Mu[0][0]']
#  bda)
#
#  tf.__operators__.getitem_307 (  ()                  0           ['tf.compat.v1.shape_31[0][0]']
#  SlicingOpLambda)
#
#  tf.random.uniform_15 (TFOpLamb  (None, 6)           0           ['tf.__operators__.getitem_307[0]
#  da)                                                             [0]']
#
#  tf.clip_by_value_46 (TFOpLambd  (None, 6)           0           ['tf.random.uniform_15[0][0]']
#  a)
#
#  tf.math.subtract_270 (TFOpLamb  (None, 6)           0           ['tf.clip_by_value_46[0][0]']
#  da)
#
#  tf.math.log_90 (TFOpLambda)    (None, 6)            0           ['tf.clip_by_value_46[0][0]']
#
#  tf.math.log_91 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_270[0][0]']
#
#  tf.math.subtract_272 (TFOpLamb  (None, 6)           0           ['tf.math.log_90[0][0]',
#  da)                                                              'tf.math.log_91[0][0]']
#
#  tf.math.log_92 (TFOpLambda)    (None, 6)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_271 (TFOpLamb  (None, 6)           0           ['FC_Mu[0][0]']
#  da)
#
#  tf.__operators__.add_187 (TFOp  (None, 6)           0           ['tf.math.subtract_272[0][0]',
#  Lambda)                                                          'tf.math.log_92[0][0]']
#
#  tf.math.log_93 (TFOpLambda)    (None, 6)            0           ['tf.math.subtract_271[0][0]']
#
#  tf.math.subtract_273 (TFOpLamb  (None, 6)           0           ['tf.__operators__.add_187[0][0]'
#  da)                                                             , 'tf.math.log_93[0][0]']
#
#  Z_Mu (Dense)                   (None, 30)           1530        ['dense_347[0][0]']
#
#  tf.math.sigmoid_15 (TFOpLambda  (None, 6)           0           ['tf.math.subtract_273[0][0]']
#  )
#
#  dense_348 (Dense)              (None, 30)           1530        ['dense_347[0][0]']
#
#  tf.compat.v1.shape_30 (TFOpLam  (2,)                0           ['Z_Mu[0][0]']
#  bda)
#
#  tf.math.multiply_540 (TFOpLamb  (None, 6)           0           ['tf.math.sigmoid_15[0][0]']
#  da)
#
#  tf.math.multiply_541 (TFOpLamb  (None, 6)           0           ['FC_Mu[0][0]']
#  da)
#
#  Z_Log_Sigma (Lambda)           (None, 30)           0           ['dense_348[0][0]']
#
#  tf.__operators__.getitem_306 (  ()                  0           ['tf.compat.v1.shape_30[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.add_188 (TFOp  (None, 6)           0           ['tf.math.multiply_540[0][0]',
#  Lambda)                                                          'tf.math.multiply_541[0][0]']
#
#  tf.math.multiply_538 (TFOpLamb  (None, 30)          0           ['Z_Log_Sigma[0][0]']
#  da)
#
#  tf.random.normal_15 (TFOpLambd  (None, 30)          0           ['tf.__operators__.getitem_306[0]
#  a)                                                              [0]']
#
#  tf.math.multiply_542 (TFOpLamb  (None, 6)           0           ['tf.__operators__.add_188[0][0]'
#  da)                                                             ]
#
#  tf.math.exp_60 (TFOpLambda)    (None, 30)           0           ['tf.math.multiply_538[0][0]']
#
#  tf.math.multiply_537 (TFOpLamb  (None, 30)          0           ['tf.random.normal_15[0][0]']
#  da)
#
#  tf.clip_by_value_47 (TFOpLambd  (None, 6)           0           ['tf.math.multiply_542[0][0]']
#  a)
#
#  tf.math.multiply_539 (TFOpLamb  (None, 30)          0           ['tf.math.exp_60[0][0]',
#  da)                                                              'tf.math.multiply_537[0][0]']
#
#  FCs (Lambda)                   (None, 6)            0           ['tf.clip_by_value_47[0][0]']
#
#  tf.__operators__.add_186 (TFOp  (None, 30)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_539[0][0]']
#
#  tf.__operators__.getitem_335 (  (None, 2)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_336 (  (None, 4)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  Zs (Lambda)                    (None, 30)           0           ['tf.__operators__.add_186[0][0]'
#                                                                  ]
#
#  SigOut (Flatten)               (None, 1000)         0           ['tf.signal.frame_57[0][0]']
#
#  FeatGenModel (Functional)      [(None, 800),        82100       ['tf.__operators__.getitem_335[0]
#                                  (None, 800),                    [0]',
#                                  (None, 800),                     'tf.__operators__.getitem_336[0]
#                                  (None, 800)]                    [0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 800),        0           ['SigOut[0][0]',
#                                  (None, 800),                     'FCs[0][0]']
#                                  (None, 800),
#                                  (None, 800)]
#
#  ReconModel (Functional)        (None, 1000)         191300      ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_76 (TFOpLambda)        (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_75 (TFOpLambda)        (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_274 (TFOpLamb  (None, 1000)        0           ['tf.cast_76[0][0]',
#  da)                                                              'tf.cast_75[0][0]']
#
#  tf.math.square_30 (TFOpLambda)  (None, 1000)        0           ['tf.math.subtract_274[0][0]']
#
#  Beta_Orig (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_90 (TFOpLa  ()                  0           ['tf.math.square_30[0][0]']
#  mbda)
#
#  tf.math.multiply_579 (TFOpLamb  ()                  0           ['Beta_Orig[0][0]',
#  da)                                                              'tf.math.reduce_mean_90[0][0]']
#
#  add_loss_60 (AddLoss)          ()                   0           ['tf.math.multiply_579[0][0]']
#
#  add_metric_60 (AddMetric)      ()                   0           ['tf.math.multiply_579[0][0]']
#
#  tf.concat_91 (TFOpLambda)      (None, 3200)         0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatExtModel[0][2]',
#                                                                   'FeatExtModel[0][3]']
#
#  tf.concat_90 (TFOpLambda)      (None, 3200)         0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]',
#                                                                   'FeatGenModel[0][2]',
#                                                                   'FeatGenModel[0][3]']
#
#  tf.cast_78 (TFOpLambda)        (None, 3200)         0           ['tf.concat_91[0][0]']
#
#  tf.cast_77 (TFOpLambda)        (None, 3200)         0           ['tf.concat_90[0][0]']
#
#  tf.math.subtract_275 (TFOpLamb  (None, 3200)        0           ['tf.cast_78[0][0]',
#  da)                                                              'tf.cast_77[0][0]']
#
#  tf.math.square_31 (TFOpLambda)  (None, 3200)        0           ['tf.math.subtract_275[0][0]']
#
#  Beta_Feat (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_91 (TFOpLa  ()                  0           ['tf.math.square_31[0][0]']
#  mbda)
#
#  tf.math.multiply_580 (TFOpLamb  ()                  0           ['Beta_Feat[0][0]',
#  da)                                                              'tf.math.reduce_mean_91[0][0]']
#
#  add_loss_61 (AddLoss)          ()                   0           ['tf.math.multiply_580[0][0]']
#
#  add_metric_61 (AddMetric)      ()                   0           ['tf.math.multiply_580[0][0]']
#
# ...
#
#  tf.__operators__.add_212 (TFOp  (None, 30)          0           ['Z_Mu[0][0]',
#  Lambda)                                                          'tf.math.multiply_625[0][0]']
#
#  tf.__operators__.getitem_369 (  (None, 0)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_370 (  (None, 2)           0           ['FCs[0][0]']
#  SlicingOpLambda)
#
#  Zs (Lambda)                    (None, 30)           0           ['tf.__operators__.add_212[0][0]'
#                                                                  ]
#
#  SigOut (Flatten)               (None, 1000)         0           ['tf.signal.frame_67[0][0]']
#
#  FeatGenModel (Functional)      [(None, 800),        40850       ['tf.__operators__.getitem_369[0]
#                                  (None, 800)]                    [0]',
#                                                                   'tf.__operators__.getitem_370[0]
#                                                                  [0]',
#                                                                   'Zs[0][0]']
#
#  FeatExtModel (Functional)      [(None, 800),        0           ['SigOut[0][0]',
#                                  (None, 800)]                     'FCs[0][0]']
#
#  ReconModel (Functional)        (None, 1000)         84900       ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]',
#                                                                   'FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]']
#
#  tf.cast_86 (TFOpLambda)        (None, 1000)         0           ['Inp_Enc[0][0]']
#
#  tf.cast_85 (TFOpLambda)        (None, 1000)         0           ['ReconModel[0][0]']
#
#  tf.math.subtract_310 (TFOpLamb  (None, 1000)        0           ['tf.cast_86[0][0]',
#  da)                                                              'tf.cast_85[0][0]']
#
#  tf.math.square_34 (TFOpLambda)  (None, 1000)        0           ['tf.math.subtract_310[0][0]']
#
#  Beta_Orig (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_102 (TFOpL  ()                  0           ['tf.math.square_34[0][0]']
#  ambda)
#
#  tf.math.multiply_641 (TFOpLamb  ()                  0           ['Beta_Orig[0][0]',
#  da)                                                              'tf.math.reduce_mean_102[0][0]']
#
#  add_loss_68 (AddLoss)          ()                   0           ['tf.math.multiply_641[0][0]']
#
#  add_metric_68 (AddMetric)      ()                   0           ['tf.math.multiply_641[0][0]']
#
#  tf.concat_101 (TFOpLambda)     (None, 1600)         0           ['FeatExtModel[0][0]',
#                                                                   'FeatExtModel[0][1]']
#
#  tf.concat_100 (TFOpLambda)     (None, 1600)         0           ['FeatGenModel[0][0]',
#                                                                   'FeatGenModel[0][1]']
#
#  tf.cast_88 (TFOpLambda)        (None, 1600)         0           ['tf.concat_101[0][0]']
#
#  tf.cast_87 (TFOpLambda)        (None, 1600)         0           ['tf.concat_100[0][0]']
#
#  tf.math.subtract_311 (TFOpLamb  (None, 1600)        0           ['tf.cast_88[0][0]',
#  da)                                                              'tf.cast_87[0][0]']
#
#  tf.math.square_35 (TFOpLambda)  (None, 1600)        0           ['tf.math.subtract_311[0][0]']
#
#  Beta_Feat (Lossweight)         ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.reduce_mean_103 (TFOpL  ()                  0           ['tf.math.square_35[0][0]']
#  ambda)
#
#  tf.math.multiply_642 (TFOpLamb  ()                  0           ['Beta_Feat[0][0]',
#  da)                                                              'tf.math.reduce_mean_103[0][0]']
#
#  add_loss_69 (AddLoss)          ()                   0           ['tf.math.multiply_642[0][0]']
#
#  add_metric_69 (AddMetric)      ()                   0           ['tf.math.multiply_642[0][0]']
#
#  tf.math.pow_17 (TFOpLambda)    (None, 30)           0           ['Z_Mu[0][0]']
#
#  tf.math.exp_71 (TFOpLambda)    (None, 30)           0           ['Z_Log_Sigma[0][0]']
#
#  tf.__operators__.add_223 (TFOp  (None, 30)          0           ['tf.math.pow_17[0][0]',
#  Lambda)                                                          'tf.math.exp_71[0][0]']
#
#  tf.math.subtract_320 (TFOpLamb  (None, 30)          0           ['tf.__operators__.add_223[0][0]'
#  da)                                                             , 'Z_Log_Sigma[0][0]']
#
#  tf.math.subtract_321 (TFOpLamb  (None, 30)          0           ['tf.math.subtract_320[0][0]']
#  da)
#
#  tf.math.reduce_sum_175 (TFOpLa  (None,)             0           ['tf.math.subtract_321[0][0]']
#  mbda)
#
#  tf.math.multiply_651 (TFOpLamb  (None,)             0           ['tf.math.reduce_sum_175[0][0]']
#  da)
#
#  tf.math.reduce_mean_107 (TFOpL  ()                  0           ['tf.math.multiply_651[0][0]']
#  ambda)
#
#  tf.math.subtract_322 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_107[0][0]']
#  da)
#
#  Beta_Z (Lossweight)            ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_34 (TFOpLambda)    ()                   0           ['tf.math.subtract_322[0][0]']
#
#  tf.math.multiply_652 (TFOpLamb  ()                  0           ['Beta_Z[0][0]',
#  da)                                                              'tf.math.abs_34[0][0]']
#
#  add_loss_70 (AddLoss)          ()                   0           ['tf.math.multiply_652[0][0]']
#
#  add_metric_70 (AddMetric)      ()                   0           ['tf.math.multiply_652[0][0]']
#
#  tf.cast_89 (TFOpLambda)        (None, 2)            0           ['FC_Mu[0][0]']
#
#  tf.math.subtract_318 (TFOpLamb  (None, 2)           0           ['tf.cast_89[0][0]']
#  da)
#
#  tf.math.log_106 (TFOpLambda)   (None, 2)            0           ['tf.cast_89[0][0]']
#
#  tf.math.log_107 (TFOpLambda)   (None, 2)            0           ['tf.math.subtract_318[0][0]']
#
#  tf.math.subtract_316 (TFOpLamb  (None, 2)           0           ['tf.math.log_106[0][0]']
#  da)
#
#  tf.math.subtract_317 (TFOpLamb  (None, 2)           0           ['tf.cast_89[0][0]']
#  da)
#
#  tf.math.subtract_319 (TFOpLamb  (None, 2)           0           ['tf.math.log_107[0][0]']
#  da)
#
#  tf.math.multiply_649 (TFOpLamb  (None, 2)           0           ['tf.cast_89[0][0]',
#  da)                                                              'tf.math.subtract_316[0][0]']
#
#  tf.math.multiply_650 (TFOpLamb  (None, 2)           0           ['tf.math.subtract_317[0][0]',
#  da)                                                              'tf.math.subtract_319[0][0]']
#
#  tf.__operators__.add_222 (TFOp  (None, 2)           0           ['tf.math.multiply_649[0][0]',
#  Lambda)                                                          'tf.math.multiply_650[0][0]']
#
#  tf.math.reduce_mean_106 (TFOpL  ()                  0           ['tf.__operators__.add_222[0][0]'
#  ambda)                                                          ]
#
#  tf.math.subtract_323 (TFOpLamb  ()                  0           ['tf.math.reduce_mean_106[0][0]']
#  da)
#
#  Beta_Fc (Lossweight)           ()                   1           ['Inp_Enc[0][0]']
#
#  tf.math.abs_35 (TFOpLambda)    ()                   0           ['tf.math.subtract_323[0][0]']
#
#  tf.math.multiply_653 (TFOpLamb  ()                  0           ['Beta_Fc[0][0]',
#  da)                                                              'tf.math.abs_35[0][0]']
#
#  add_loss_71 (AddLoss)          ()                   0           ['tf.math.multiply_653[0][0]']
#
#  add_metric_71 (AddMetric)      ()                   0           ['tf.math.multiply_653[0][0]']
#
# ==================================================================================================
# Total params: 234,892
# Trainable params: 234,888
# Non-trainable params: 4
# __________________________________________________________________________________________________
# Model weights loaded
# 19/19 [==============================] - 2s 9ms/step
# 19/19 [==============================] - 2s 11ms/step

# %% [markdown]
# ### Visualization
# #### Note: The use of simulated data for visualization may result in reduced quality.

# %%
# -*- coding: utf-8 -*-
# =========================
# Figure-wide style (Nature-ish, full spines)
# =========================
mpl.rcParams.update({
    "font.family": "sans-serif",
    "font.sans-serif": ["Arial", "DejaVu Sans"],
    "font.size": 14,
    "axes.titlesize": 16,
    "axes.labelsize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
    "axes.linewidth": 1.2,
    "figure.dpi": 300,
    "axes.spines.top": True,
    "axes.spines.right": True,
    "axes.spines.left": True,
    "axes.spines.bottom": True,
})

# =========================
# Assumed globals in the session
# =========================
N_Gen = sum(DicParam['ART_VitalDB']['N_GenList'])
keys = [ConfigName[0] for ConfigItems in DicConfigYaml.items() for ConfigName in ConfigItems[1].items()]

# Figure layout: 2 rows × 4 columns (Signal | cbar | Signal | cbar)
n_rows = 2
n_cols = 4

# =========================
# Colormap
# =========================
signal_cmap = plt.get_cmap('viridis')
psd_cmap_name = 'turbo'

# =========================
# Label mappings
# =========================
model_labels = {'SKZFC': 'VABAM'}
signal_types = {'ART': 'ABP', 'II': 'ECG'}

def _model_label_from_key(k):
    for kk, vv in model_labels.items():
        if kk in k:
            return vv
    return 'Unknown'

def _signal_label_from_key(k):
    for kk, vv in signal_types.items():
        if kk in k:
            return vv
    return 'Signal'

def _source_tag(k):
    if 'VitalDB' in k: return 'VitalDB'
    if 'Mimic' in k or 'MIMIC' in k: return 'MIMIC'
    return ''

# =========================
# Enhanced Colorbar configuration
# =========================
CBAR_CONFIG = {
    "signal": {
        "pos_min": "right", "dx_min": 0.4, "dy_min": -0.05, "dx_min_pt": 0, "dy_min_pt": 0,
        "pos_max": "right", "dx_max": 0.4, "dy_max": 0.05, "dx_max_pt": 0, "dy_max_pt": 0,
        "pad": 0.08
    },
    "psd": {
        "pos_min": "right", "dx_min": 0.4, "dy_min": -0.05, "dx_min_pt": 0, "dy_min_pt": 0,
        "pos_max": "right", "dx_max": 0.4, "dy_max": 0.05, "dx_max_pt": 0, "dy_max_pt": 0,
        "pad": 0.08
    }
}

# =========================
# Helpers
# =========================
def _format_tick_value(v):
    if np.isfinite(v) and abs(v - np.round(v)) < 1e-9:
        return f"{int(np.round(v))}"
    s = f"{v:.2f}".rstrip('0').rstrip('.')
    return s if s else "0"

def _axes_plus_pt(ax, dx_pt=0, dy_pt=0):
    return ax.transAxes + transforms.ScaledTranslation(dx_pt/72, dy_pt/72, ax.figure.dpi_scale_trans)

def _place_label(ax, text, pos, dx, dy, dx_pt=0, dy_pt=0, is_min=True, fontsize=13):
    if pos in ('right', 'left'):
        y = 0.0 if is_min else 1.0
        x = 1.0 if pos == 'right' else 0.0
        ha = 'left' if pos == 'right' else 'right'
        va = 'bottom' if is_min else 'top'
        trans = _axes_plus_pt(ax, dx_pt=dx_pt, dy_pt=dy_pt)
        ax.text(x + dx, y + dy, text, transform=trans, ha=ha, va=va,
                fontsize=fontsize, clip_on=False, zorder=1000, color='black')
    elif pos == 'top':
        x, y = 0.5, 1.0
        ha, va = 'center', 'bottom'
        trans = _axes_plus_pt(ax, dx_pt=dx_pt, dy_pt=dy_pt)
        ax.text(x + dx, y + dy, text, transform=trans, ha=ha, va=va,
                fontsize=fontsize, clip_on=False, zorder=1000, color='black')
    elif pos == 'bottom':
        x, y = 0.5, 0.0
        ha, va = 'center', 'top'
        trans = _axes_plus_pt(ax, dx_pt=dx_pt, dy_pt=dy_pt)
        ax.text(x + dx, y + dy, text, transform=trans, ha=ha, va=va,
                fontsize=fontsize, clip_on=False, zorder=1000, color='black')
    else:
        _place_label(ax, text, 'right', dx, dy, dx_pt, dy_pt, is_min, fontsize)

def _decorate_cbar_end_labels(
    cbar, vmin, vmax,
    pos_min='right', dx_min=0.00, dy_min=0.00, dx_min_pt=0, dy_min_pt=0,
    pos_max='right', dx_max=0.00, dy_max=0.00, dx_max_pt=0, dy_max_pt=0,
    fontsize=13
):
    cbar.locator = ticker.FixedLocator([vmin, vmax])
    cbar.formatter = ticker.FixedFormatter(['', ''])
    cbar.update_ticks()
    cbar.ax.tick_params(which='both', length=0, pad=0)
    
    if cbar.outline:
        cbar.outline.set_linewidth(1.0)
    
    _place_label(cbar.ax, _format_tick_value(vmin), pos_min, dx_min, dy_min,
                 dx_min_pt, dy_min_pt, is_min=True, fontsize=fontsize)
    _place_label(cbar.ax, _format_tick_value(vmax), pos_max, dx_max, dy_max,
                 dx_max_pt, dy_max_pt, is_min=False, fontsize=fontsize)

# -------------------------------------------------
# Organize keys by signal type (ABP and ECG)
# -------------------------------------------------
signal_pairs = {'ABP': {'MIMIC': None, 'VitalDB': None}, 
                'ECG': {'MIMIC': None, 'VitalDB': None}}

for k in keys:
    sig_type = _signal_label_from_key(k)
    src = _source_tag(k)
    if sig_type in signal_pairs and src in signal_pairs[sig_type]:
        if signal_pairs[sig_type][src] is None:
            signal_pairs[sig_type][src] = k

# Build pairs list: Row 0 = ABP, Row 1 = ECG
pairs = [signal_pairs['ABP'], signal_pairs['ECG']]

# =========================
# Figure & GridSpec
# =========================
fig = plt.figure(figsize=(20, 6))
gs = GridSpec(n_rows, n_cols, figure=fig,
              width_ratios=[3.8, 1.2, 3.8, 1.2],
              hspace=0.4, wspace=0.2)

gt_handle = None
row_left_sig_axes, row_signal_names = [], []

# =========================
# Render one cell (Signal + PSD) for a given key
# =========================
def _render_cell(row, pos_in_row, key):
    col_signal = 0 if pos_in_row == 0 else 2
    col_psd = col_signal + 1

    if key is None:
        ax_empty_s = fig.add_subplot(gs[row, col_signal])
        ax_empty_p = fig.add_subplot(gs[row, col_psd])
        for ax in (ax_empty_s, ax_empty_p):
            ax.set_xticks([]); ax.set_yticks([])
            for spine in ax.spines.values():
                spine.set_color('black'); spine.set_linewidth(1.2); spine.set_visible(True)
        ax_empty_s.text(0.5, 0.5, 'No data', ha='center', va='center', fontsize=12)
        ax_empty_p.text(0.5, 0.5, 'No data', ha='center', va='center', fontsize=12)
        return ax_empty_s, ax_empty_p, None

    model_name = _model_label_from_key(key)
    signal_name = _signal_label_from_key(key)

    # Get the appropriate MinFreqR and MaxFreqR for this key
    for config_key in DicParam.keys():
        if config_key.split('_')[0] in key and config_key.split('_')[1] in key:
            MinFreqR = DicParam[config_key]['MinFreqR']
            MaxFreqR = DicParam[config_key]['MaxFreqR']
            break

    param_values = np.linspace(MinFreqR, MaxFreqR, N_Gen)
    param_norm = plt.Normalize(MinFreqR, MaxFreqR)
    param_label = r'Filter coefficient $\theta$'

    # ----- Signal plot -----
    ax_signal = fig.add_subplot(gs[row, col_signal])
    for i in range(N_Gen):
        color = signal_cmap(param_norm(param_values[i] if i < len(param_values) else i))
        ax_signal.plot(GeneratedSignals[key][i], color=color, alpha=0.8, linewidth=1.0)

    gt_line, = ax_signal.plot(
        InpSignals[key][0], color='#d62728', linewidth=2.5, label='Ground truth'
    )
    global gt_handle
    if gt_handle is None:
        gt_handle = gt_line

    ax_signal.set_title(model_name, fontweight='bold', fontsize=18)
    ax_signal.set_xticks([]); ax_signal.set_yticks([])
    for spine in ax_signal.spines.values():
        spine.set_color('black'); spine.set_linewidth(1.2); spine.set_visible(True)

    # ----- Signal colorbar -----
    divider1 = make_axes_locatable(ax_signal)
    cax1 = divider1.append_axes("right", size="2.5%", pad=CBAR_CONFIG["signal"]["pad"])
    sm1 = plt.cm.ScalarMappable(cmap=signal_cmap, norm=param_norm); sm1.set_array([])
    cbar1 = fig.colorbar(sm1, cax=cax1)
    cbar1.set_label(param_label, fontsize=14, rotation=-90, labelpad=15)

    _decorate_cbar_end_labels(
        cbar1, param_norm.vmin, param_norm.vmax,
        pos_min=CBAR_CONFIG["signal"]["pos_min"],
        dx_min=CBAR_CONFIG["signal"]["dx_min"], dy_min=CBAR_CONFIG["signal"]["dy_min"],
        dx_min_pt=CBAR_CONFIG["signal"]["dx_min_pt"], dy_min_pt=CBAR_CONFIG["signal"]["dy_min_pt"],
        pos_max=CBAR_CONFIG["signal"]["pos_max"],
        dx_max=CBAR_CONFIG["signal"]["dx_max"], dy_max=CBAR_CONFIG["signal"]["dy_max"],
        dx_max_pt=CBAR_CONFIG["signal"]["dx_max_pt"], dy_max_pt=CBAR_CONFIG["signal"]["dy_max_pt"],
        fontsize=12
    )

    # ----- PSD heatmap -----
    ax_psd = fig.add_subplot(gs[row, col_psd])
    heatmap_data = GeneratedAmplitude[key][:, MinFreq:MaxFreq]
    im = ax_psd.imshow(
        heatmap_data, cmap=psd_cmap_name, aspect='auto',
        interpolation='bilinear', origin='lower'
    )
    ax_psd.set_title('PSD', fontsize=16)
    ax_psd.set_xticks([]); ax_psd.set_yticks([])
    ax_psd.set_xlabel('Frequency (Hz)', fontsize=14)
    ax_psd.set_ylabel('Generation index', fontsize=14)
    for spine in ax_psd.spines.values():
        spine.set_color('black'); spine.set_linewidth(1.2); spine.set_visible(True)

    # ----- PSD colorbar -----
    divider2 = make_axes_locatable(ax_psd)
    cax2 = divider2.append_axes("right", size="5%", pad=CBAR_CONFIG["psd"]["pad"])
    cbar2 = fig.colorbar(im, cax=cax2)
    cbar2.set_label('Power', fontsize=14, rotation=-90, labelpad=14)
    vmin, vmax = im.norm.vmin, im.norm.vmax

    _decorate_cbar_end_labels(
        cbar2, vmin, vmax,
        pos_min=CBAR_CONFIG["psd"]["pos_min"],
        dx_min=CBAR_CONFIG["psd"]["dx_min"], dy_min=CBAR_CONFIG["psd"]["dy_min"],
        dx_min_pt=CBAR_CONFIG["psd"]["dx_min_pt"], dy_min_pt=CBAR_CONFIG["psd"]["dy_min_pt"],
        pos_max=CBAR_CONFIG["psd"]["pos_max"],
        dx_max=CBAR_CONFIG["psd"]["dx_max"], dy_max=CBAR_CONFIG["psd"]["dy_max"],
        dx_max_pt=CBAR_CONFIG["psd"]["dx_max_pt"], dy_max_pt=CBAR_CONFIG["psd"]["dy_max_pt"],
        fontsize=12
    )

    return ax_signal, ax_psd, signal_name

# =========================
# Render rows (left=MIMIC, right=VitalDB)
# =========================
first_row_left_axes = None
first_row_right_axes = None

for row_idx in range(n_rows):
    pair = pairs[row_idx]
    left_out = _render_cell(row_idx, 0, pair.get('MIMIC'))
    right_out = _render_cell(row_idx, 1, pair.get('VitalDB'))
    
    if row_idx == 0:
        first_row_left_axes = (left_out[0], left_out[1])
        first_row_right_axes = (right_out[0], right_out[1])
    
    chosen_signal = (left_out[2] or right_out[2] or 'Signal')
    row_signal_names.append(chosen_signal)
    row_left_sig_axes.append(left_out[0] if left_out[0] is not None else right_out[0])

# =========================
# Global legend
# =========================
if gt_handle is not None:
    fig.legend(handles=[gt_handle], labels=['Ground truth'],
               loc='upper right', bbox_to_anchor=(0.19, 1.04),
               frameon=True, fontsize=15, shadow=False)

# =========================
# Top group headers (MIMIC / VitalDB)
# =========================
if first_row_left_axes is not None and first_row_right_axes is not None:
    left_sig_ax, left_psd_ax = first_row_left_axes
    right_sig_ax, right_psd_ax = first_row_right_axes
    left_pos_start = left_sig_ax.get_position()
    left_pos_end = left_psd_ax.get_position()
    right_pos_start = right_sig_ax.get_position()
    right_pos_end = right_psd_ax.get_position()

    group1_x0 = left_pos_start.x0 - 0.035
    group1_x1 = left_pos_end.x1 + 0.01
    group2_x0 = right_pos_start.x0 + 0.013
    group2_x1 = right_pos_end.x1 + 0.06

    top_y = max(left_pos_start.y1, left_pos_end.y1, right_pos_start.y1, right_pos_end.y1) + 0.15
    bar_height = 0.01

    fig.patches.extend([
        Rectangle((group1_x0, top_y), group1_x1 - group1_x0, bar_height,
                  transform=fig.transFigure, facecolor="#cfcfcf", alpha=0.4, zorder=0),
        Rectangle((group2_x0, top_y), group2_x1 - group2_x0, bar_height,
                  transform=fig.transFigure, facecolor="#cfcfcf", alpha=0.4, zorder=0)
    ])
    fig.text((group1_x0 + group1_x1)/2, top_y + bar_height + 0.005, "MIMIC",
             ha='center', va='bottom', fontsize=20, fontweight='bold')
    fig.text((group2_x0 + group2_x1)/2, top_y + bar_height + 0.005, "VitalDB",
             ha='center', va='bottom', fontsize=20, fontweight='bold')

# =========================
# Vertical left-side labels (ABP / ECG)
# =========================
for ax_left, sig_name in zip(row_left_sig_axes, row_signal_names):
    if ax_left is None:
        continue
    ax_left.text(-0.04, 0.5, sig_name,
                 transform=ax_left.transAxes,
                 rotation=90, va='center', ha='center',
                 fontsize=16, clip_on=False)

# =========================
# Final layout
# =========================
plt.subplots_adjust(top=0.96, bottom=0.04, left=0.09, right=0.96)
plt.show()
