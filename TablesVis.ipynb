# %% [markdown]
# ###  Module & Utility Imports
# #### Note: “In the revised version of the paper, MS has been replaced with Shape Factorization (SF).”

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ### Comparison between the main model and benchmark models w/ SF (Main manuscript)

# %%
# === Load CSV ===
df = pd.read_csv('./EvalResults/SummaryTables/BenchCompTabs.csv')
df = df.rename(columns={'MS':'SF', 'MP':'SP'})

# === 모델명 정규화 ===
df["Model"] = df["Model"].str.replace(r".*SKZFC.*", "VABAM", regex=True)

def normalize_model(s: str) -> str:
    if s.startswith("ConVAE"):   return "C-VAE"
    if s.startswith("FACVAE"):   return "FAC-VAE"
    if s.startswith("TCVAE"):    return "TC-VAE"
    if s.startswith("VDVAE"):    return "VD-VAE"
    if s.startswith("DiffWave"): return "DiffWave"
    if s.startswith("VDWave"):   return "VDWave"
    if s.startswith("Wavenet"):  return "WaveNet"
    return s

df["Model"] = df["Model"].map(normalize_model)

# === Type 값 변경: ART -> ABP, II -> ECG ===
df["Type"] = df["Type"].replace({"ART": "ABP", "II": "ECG"})

# === Metric Label ===
metric_map = {"fft":"Fast Fourier Transform","matching_pursuit":"Discrete Cosine Transform","welch_evo":"Welch-based Spectral Evolution"}
df["MetricLabel"] = df["MetricType"].map(metric_map)

# === Source × Type 조합별 Subtable ===
source_list = df["Source"].dropna().unique()
type_list   = df["Type"].dropna().unique()
metric_order = ["Fast Fourier Transform","Discrete Cosine Transform","Welch-based Spectral Evolution"]
score_cols = ["ISCOREhm","ISCOREgm", "ISCOREam"]

# 컬럼 구조 생성
col_tuples = [("Dataset – Signal","Model")]
for met in metric_order:
    for sc in score_cols:
        sc_label = sc.replace("ISCORE","").upper()  # AM, GM, HM
        col_tuples.append((met, sc_label))

num_expected_cols = len(col_tuples)

all_rows = []
first_table = True

for s in source_list:
    for t in type_list:
        sub = df[(df["Source"]==s) & (df["Type"]==t)].copy()
        if sub.empty:
            continue

        if not first_table:
            all_rows.append([""]*num_expected_cols)

        header_row = [f"\\textbf{{{s} – {t}}}"] + [""]*(num_expected_cols-1)
        all_rows.append(header_row)

        model_order = ["C-VAE","FAC-VAE","TC-VAE","VD-VAE","DiffWave","VDWave","WaveNet","VABAM"]
        sub["Model"] = pd.Categorical(sub["Model"], categories=model_order, ordered=True)
        sub = sub.sort_values("Model")

        wide = sub.pivot(index="Model", columns="MetricLabel", values=score_cols)
        wide = wide.swaplevel(0,1,axis=1).sort_index(axis=1, level=0)

        ordered_cols = []
        for met in metric_order:
            for sc in score_cols:
                if (met, sc) in wide.columns:
                    ordered_cols.append((met, sc))
        wide = wide[ordered_cols]

        style_map = {}
        for col in wide.columns:
            vals = wide[col].dropna()
            order = vals.sort_values(ascending=False).index.tolist()
            style_map[col] = {"first": order[0] if len(order)>0 else None,
                              "second": order[1] if len(order)>1 else None}

        for model in wide.index:
            row = [f"\\textbf{{{model}}}" if model=="VABAM" else model]
            for col in wide.columns:
                x = wide.loc[model,col]
                if pd.isna(x):
                    row.append("")
                else:
                    xfmt = f"{x:.3f}"
                    if model == style_map[col]["first"]:
                        row.append(f"\\textbf{{{xfmt}}}")
                    elif model == style_map[col]["second"]:
                        row.append(f"\\underline{{{xfmt}}}")
                    else:
                        row.append(xfmt)
            all_rows.append(row)

        first_table = False

combined_df = pd.DataFrame(all_rows, columns=pd.MultiIndex.from_tuples(col_tuples))

# 기존 포맷 유지
col_format = "l|" + "|".join(["c"*len(score_cols)]*len(metric_order))

latex = combined_df.to_latex(
    index=False,
    escape=False,
    multicolumn=True,
    multicolumn_format="c",
    column_format=col_format,
    caption=(
        "\\textbf{ISCORE-based comparison of ABP and ECG synthesis on MIMIC and VitalDB using all metric components.} "
        "Reported metrics include waveform shape factorization (SF~$\\uparrow$), "
        "shape preservation (SP~$\\uparrow$), "
        "amplitude modulation controllability (AC~$\\uparrow$), "
        "spectral similarity (SS~$\\uparrow$) and reconstructive accuracy (RA~$\\uparrow$), "
        "together with three aggregated ISCORE measures—arithmetic mean (AM), geometric mean (GM) and harmonic mean (HM). "
        "For DiffWave, VDWave and WaveNet, SF was excluded from the ISCORE calculation. "
        "Boldface and underlining indicate the best and second-best results, respectively."
    ),
    label="tab:performance_comparison_all"

)

# 위치 지정자 추가
latex = latex.replace("\\begin{table}", "\\begin{table}[!htbp]")

# === FFT/MP/Welch 오른쪽에 수직선 추가 ===
# multicolumn{3}{c}{FFT} → multicolumn{3}{c|}{FFT} 식으로 변경
latex = latex.replace("& \\multicolumn{3}{c}{Fast Fourier Transform}", "& \\multicolumn{3}{c|}{Fast Fourier Transform}")
latex = latex.replace("& \\multicolumn{3}{c}{Matching Pursuit}", "& \\multicolumn{3}{c|}{Matching Pursuit}")
# 마지막 Welch Evolution은 오른쪽에 더 이상 블록 없으므로 굳이 '|' 안 넣어도 무방
# 필요하면 아래 주석 해제
latex = latex.replace("& \\multicolumn{3}{c}{Welch-based Spectral Evolution}", "& \\multicolumn{3}{c}{Welch-based Spectral Evolution}")

# captionsetup 유지
latex_with_setup = "\\captionsetup{font=footnotesize, margin=-12pt}\n" + latex

print(latex_with_setup)
# Out:
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{ISCORE-based comparison of ABP and ECG synthesis on MIMIC and VitalDB using all metric components.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$) and reconstructive accuracy (RA~$\uparrow$), together with three aggregated ISCORE measures—arithmetic mean (AM), geometric mean (GM) and harmonic mean (HM). For DiffWave, VDWave and WaveNet, SF was excluded from the ISCORE calculation. Boldface and underlining indicate the best and second-best results, respectively.}
# \label{tab:performance_comparison_all}
# \begin{tabular}{l|ccc|ccc|ccc}
# \toprule
# Dataset – Signal & \multicolumn{3}{c|}{Fast Fourier Transform} & \multicolumn{3}{c}{Discrete Cosine Transform} & \multicolumn{3}{c}{Welch-based Spectral Evolution} \\
# Model & HM & GM & AM & HM & GM & AM & HM & GM & AM \\
# \midrule
# \textbf{Mimic – ABP} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.250 & 0.392 & 0.521 & 0.156 & 0.378 & 0.558 & \underline{0.445} & 0.526 & 0.595 \\
# FAC-VAE & 0.245 & 0.391 & 0.520 & 0.107 & 0.346 & 0.557 & 0.442 & \underline{0.531} & 0.608 \\
# TC-VAE & 0.089 & 0.322 & 0.539 & 0.034 & 0.277 & 0.567 & 0.419 & 0.501 & 0.579 \\
# VD-VAE & 0.132 & 0.315 & 0.485 & 0.070 & 0.298 & 0.527 & 0.424 & 0.489 & 0.558 \\
# DiffWave & 0.116 & 0.376 & 0.655 & 0.156 & \underline{0.420} & 0.677 & 0.301 & 0.480 & 0.637 \\
# VDWave & 0.106 & 0.368 & \underline{0.657} & 0.136 & 0.404 & \underline{0.678} & 0.269 & 0.468 & \underline{0.644} \\
# WaveNet & \underline{0.381} & \underline{0.449} & 0.531 & \underline{0.246} & 0.413 & 0.567 & 0.340 & 0.404 & 0.485 \\
# \textbf{VABAM} & \textbf{0.801} & \textbf{0.817} & \textbf{0.833} & \textbf{0.776} & \textbf{0.796} & \textbf{0.816} & \textbf{0.864} & \textbf{0.870} & \textbf{0.875} \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{Mimic – ECG} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.079 & 0.295 & 0.510 & 0.027 & 0.203 & 0.469 & 0.342 & 0.449 & 0.539 \\
# FAC-VAE & 0.039 & 0.242 & 0.477 & 0.029 & 0.195 & 0.437 & 0.253 & 0.405 & 0.523 \\
# TC-VAE & \underline{0.210} & 0.306 & 0.430 & 0.153 & 0.237 & 0.391 & 0.167 & 0.268 & 0.399 \\
# VD-VAE & 0.160 & 0.299 & 0.396 & 0.093 & 0.243 & 0.383 & \underline{0.473} & \underline{0.489} & 0.505 \\
# DiffWave & 0.113 & \underline{0.387} & \underline{0.678} & \textbf{0.406} & \textbf{0.566} & \underline{0.692} & 0.161 & 0.426 & \underline{0.679} \\
# VDWave & 0.105 & 0.380 & \textbf{0.680} & 0.390 & \underline{0.561} & \textbf{0.695} & 0.120 & 0.393 & \textbf{0.681} \\
# WaveNet & 0.125 & 0.164 & 0.232 & 0.022 & 0.095 & 0.240 & 0.134 & 0.175 & 0.237 \\
# \textbf{VABAM} & \textbf{0.528} & \textbf{0.571} & 0.623 & \underline{0.390} & 0.468 & 0.559 & \textbf{0.596} & \textbf{0.631} & 0.667 \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{VitalDB – ABP} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.135 & 0.348 & 0.545 & 0.074 & 0.340 & 0.597 & 0.406 & 0.500 & 0.591 \\
# FAC-VAE & 0.174 & 0.366 & 0.534 & 0.078 & 0.336 & 0.581 & 0.419 & \underline{0.506} & 0.589 \\
# TC-VAE & 0.244 & \underline{0.403} & 0.535 & 0.148 & 0.381 & 0.578 & \underline{0.428} & 0.489 & 0.558 \\
# VD-VAE & 0.137 & 0.332 & 0.515 & 0.066 & 0.314 & 0.562 & 0.391 & 0.485 & 0.574 \\
# DiffWave & 0.113 & 0.386 & \underline{0.680} & \underline{0.194} & \underline{0.456} & 0.695 & 0.245 & 0.442 & 0.618 \\
# VDWave & 0.106 & 0.379 & 0.679 & 0.169 & 0.438 & \underline{0.695} & 0.203 & 0.418 & \underline{0.619} \\
# WaveNet & \underline{0.250} & 0.367 & 0.506 & 0.105 & 0.304 & 0.540 & 0.232 & 0.339 & 0.465 \\
# \textbf{VABAM} & \textbf{0.851} & \textbf{0.860} & \textbf{0.868} & \textbf{0.829} & \textbf{0.841} & \textbf{0.852} & \textbf{0.893} & \textbf{0.894} & \textbf{0.895} \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{VitalDB – ECG} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.123 & 0.381 & 0.598 & 0.049 & 0.298 & 0.576 & 0.536 & 0.598 & \underline{0.645} \\
# FAC-VAE & 0.092 & 0.368 & 0.616 & 0.048 & 0.310 & 0.597 & 0.441 & 0.551 & 0.631 \\
# TC-VAE & 0.330 & \underline{0.465} & 0.563 & 0.189 & 0.397 & 0.560 & \underline{0.585} & \underline{0.599} & 0.615 \\
# VD-VAE & 0.113 & 0.364 & 0.574 & 0.068 & 0.320 & 0.569 & 0.347 & 0.489 & 0.597 \\
# DiffWave & 0.103 & 0.353 & 0.623 & 0.332 & 0.481 & 0.608 & 0.128 & 0.378 & 0.630 \\
# VDWave & 0.102 & 0.353 & \underline{0.625} & \underline{0.333} & \underline{0.483} & \underline{0.610} & 0.126 & 0.381 & 0.641 \\
# WaveNet & \underline{0.363} & 0.409 & 0.459 & 0.155 & 0.298 & 0.426 & 0.444 & 0.471 & 0.500 \\
# \textbf{VABAM} & \textbf{0.644} & \textbf{0.678} & \textbf{0.712} & \textbf{0.508} & \textbf{0.588} & \textbf{0.662} & \textbf{0.759} & \textbf{0.761} & \textbf{0.762} \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Comparison between the main model and benchmark models w/o SF (Main manuscript)

# %%
import pandas as pd
import re

# === Load CSV ===
df = pd.read_csv('./EvalResults/SummaryTables/BenchCompTabs_NOMS.csv')
df = df.rename(columns={'MS':'SF', 'MP':'SP'})

# === 모델명 정규화 ===
df["Model"] = df["Model"].str.replace(r".*SKZFC.*", "VABAM", regex=True)

def normalize_model(s: str) -> str:
    if s.startswith("ConVAE"):   return "C-VAE"
    if s.startswith("FACVAE"):   return "FAC-VAE"
    if s.startswith("TCVAE"):    return "TC-VAE"
    if s.startswith("VDVAE"):    return "VD-VAE"
    if s.startswith("DiffWave"): return "DiffWave"
    if s.startswith("VDWave"):   return "VDWave"
    if s.startswith("Wavenet"):  return "WaveNet"
    return s

df["Model"] = df["Model"].map(normalize_model)

# === Type 값 변경: ART -> ABP, II -> ECG ===
df["Type"] = df["Type"].replace({"ART": "ABP", "II": "ECG"})

# === Metric Label ===
metric_map = {"fft":"Fast Fourier Transform","matching_pursuit":"Discrete Cosine Transform","welch_evo":"Welch-based Spectral Evolution"}
df["MetricLabel"] = df["MetricType"].map(metric_map)

# === Source × Type 조합별 Subtable ===
source_list = df["Source"].dropna().unique()
type_list   = df["Type"].dropna().unique()
metric_order = ["Fast Fourier Transform","Discrete Cosine Transform","Welch-based Spectral Evolution"]
score_cols = ["ISCOREhm","ISCOREgm","ISCOREam"]

# 컬럼 구조 생성
col_tuples = [("Dataset – Signal","Model")]
for met in metric_order:
    for sc in score_cols:
        sc_label = sc.replace("ISCORE","").upper()  # AM, GM, HM
        col_tuples.append((met, sc_label))

num_expected_cols = len(col_tuples)

all_rows = []
first_table = True

for s in source_list:
    for t in type_list:
        sub = df[(df["Source"]==s) & (df["Type"]==t)].copy()
        if sub.empty:
            continue

        if not first_table:
            all_rows.append([""]*num_expected_cols)

        header_row = [f"\\textbf{{{s} – {t}}}"] + [""]*(num_expected_cols-1)
        all_rows.append(header_row)

        model_order = ["C-VAE","FAC-VAE","TC-VAE","VD-VAE","DiffWave","VDWave","WaveNet","VABAM"]
        sub["Model"] = pd.Categorical(sub["Model"], categories=model_order, ordered=True)
        sub = sub.sort_values("Model")

        wide = sub.pivot(index="Model", columns="MetricLabel", values=score_cols)
        wide = wide.swaplevel(0,1,axis=1).sort_index(axis=1, level=0)

        ordered_cols = []
        for met in metric_order:
            for sc in score_cols:
                if (met, sc) in wide.columns:
                    ordered_cols.append((met, sc))
        wide = wide[ordered_cols]

        style_map = {}
        for col in wide.columns:
            vals = wide[col].dropna()
            order = vals.sort_values(ascending=False).index.tolist()
            style_map[col] = {"first": order[0] if len(order)>0 else None,
                              "second": order[1] if len(order)>1 else None}

        for model in wide.index:
            row = [f"\\textbf{{{model}}}" if model=="VABAM" else model]
            for col in wide.columns:
                x = wide.loc[model,col]
                if pd.isna(x):
                    row.append("")
                else:
                    xfmt = f"{x:.3f}"
                    if model == style_map[col]["first"]:
                        row.append(f"\\textbf{{{xfmt}}}")
                    elif model == style_map[col]["second"]:
                        row.append(f"\\underline{{{xfmt}}}")
                    else:
                        row.append(xfmt)
            all_rows.append(row)

        first_table = False

combined_df = pd.DataFrame(all_rows, columns=pd.MultiIndex.from_tuples(col_tuples))

# 기존 포맷 유지
col_format = "l|" + "|".join(["c"*len(score_cols)]*len(metric_order))

latex = combined_df.to_latex(
    index=False,
    escape=False,
    multicolumn=True,
    multicolumn_format="c",
    column_format=col_format,
caption=(
        "\\textbf{ISCORE-based comparison of ABP and ECG synthesis on MIMIC and VitalDB without waveform shape factorization (SF).} "
        "Reported metrics include shape preservation (SP~$\\uparrow$), "
        "amplitude modulation controllability (AC~$\\uparrow$), "
        "spectral similarity (SS~$\\uparrow$) and reconstructive accuracy (RA~$\\uparrow$), "
        "together with three aggregated ISCORE measures—arithmetic mean (AM), geometric mean (GM) and harmonic mean (HM). "
        "Boldface and underlining indicate the best and second-best results, respectively."
    ),
    label="tab:performance_comparison_noSF"
)

# 위치 지정자 추가
latex = latex.replace("\\begin{table}", "\\begin{table}[!htbp]")

# === FFT/MP/Welch 오른쪽에 수직선 추가 ===
# multicolumn{3}{c}{FFT} → multicolumn{3}{c|}{FFT} 식으로 변경
latex = latex.replace("& \\multicolumn{3}{c}{Fast Fourier Transform}", "& \\multicolumn{3}{c|}{Fast Fourier Transform}")
latex = latex.replace("& \\multicolumn{3}{c}{Matching Pursuit}", "& \\multicolumn{3}{c|}{Matching Pursuit}")
# 마지막 Welch Evolution은 오른쪽에 더 이상 블록 없으므로 굳이 '|' 안 넣어도 무방
# 필요하면 아래 주석 해제
latex = latex.replace("& \\multicolumn{3}{c}{Welch-based Spectral Evolution}", "& \\multicolumn{3}{c}{Welch-based Spectral Evolution}")

# captionsetup 유지
latex_with_setup = "\\captionsetup{font=footnotesize, margin=-12pt}\n" + latex

print(latex_with_setup)
# Out:
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{ISCORE-based comparison of ABP and ECG synthesis on MIMIC and VitalDB without waveform shape factorization (SF).} Reported metrics include shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$) and reconstructive accuracy (RA~$\uparrow$), together with three aggregated ISCORE measures—arithmetic mean (AM), geometric mean (GM) and harmonic mean (HM). Boldface and underlining indicate the best and second-best results, respectively.}
# \label{tab:performance_comparison_noSF}
# \begin{tabular}{l|ccc|ccc|ccc}
# \toprule
# Dataset – Signal & \multicolumn{3}{c|}{Fast Fourier Transform} & \multicolumn{3}{c}{Discrete Cosine Transform} & \multicolumn{3}{c}{Welch-based Spectral Evolution} \\
# Model & HM & GM & AM & HM & GM & AM & HM & GM & AM \\
# \midrule
# \textbf{Mimic – ABP} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.238 & 0.415 & 0.574 & 0.133 & 0.346 & 0.563 & 0.652 & 0.673 & 0.695 \\
# FAC-VAE & 0.229 & 0.405 & 0.565 & 0.089 & 0.306 & 0.553 & \underline{0.663} & \underline{0.687} & \underline{0.712} \\
# TC-VAE & 0.074 & 0.292 & 0.554 & 0.028 & 0.225 & 0.549 & 0.435 & 0.542 & 0.633 \\
# VD-VAE & 0.115 & 0.308 & 0.520 & 0.057 & 0.255 & 0.520 & 0.563 & 0.603 & 0.644 \\
# DiffWave & 0.116 & 0.376 & 0.655 & 0.156 & \underline{0.420} & 0.677 & 0.301 & 0.480 & 0.637 \\
# VDWave & 0.106 & 0.368 & \underline{0.657} & 0.136 & 0.404 & \underline{0.678} & 0.269 & 0.468 & 0.644 \\
# WaveNet & \underline{0.381} & \underline{0.449} & 0.531 & \underline{0.246} & 0.413 & 0.567 & 0.340 & 0.404 & 0.485 \\
# \textbf{VABAM} & \textbf{0.763} & \textbf{0.777} & \textbf{0.792} & \textbf{0.734} & \textbf{0.752} & \textbf{0.770} & \textbf{0.850} & \textbf{0.856} & \textbf{0.862} \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{Mimic – ECG} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.064 & 0.218 & 0.394 & 0.022 & 0.137 & 0.343 & 0.297 & 0.379 & 0.454 \\
# FAC-VAE & 0.031 & 0.174 & 0.369 & 0.024 & 0.133 & 0.320 & 0.215 & 0.336 & 0.441 \\
# TC-VAE & \underline{0.177} & 0.238 & 0.330 & 0.127 & 0.171 & 0.270 & 0.143 & 0.226 & 0.368 \\
# VD-VAE & 0.137 & 0.265 & 0.375 & 0.076 & 0.191 & 0.319 & \underline{0.481} & \underline{0.502} & 0.520 \\
# DiffWave & 0.113 & \underline{0.387} & \underline{0.678} & \textbf{0.406} & \textbf{0.566} & \underline{0.692} & 0.161 & 0.426 & \underline{0.679} \\
# VDWave & 0.105 & 0.380 & \textbf{0.680} & \underline{0.390} & \underline{0.561} & \textbf{0.695} & 0.120 & 0.393 & \textbf{0.681} \\
# WaveNet & 0.125 & 0.164 & 0.232 & 0.022 & 0.095 & 0.240 & 0.134 & 0.175 & 0.237 \\
# \textbf{VABAM} & \textbf{0.472} & \textbf{0.497} & 0.530 & 0.338 & 0.387 & 0.449 & \textbf{0.546} & \textbf{0.571} & 0.599 \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{VitalDB – ABP} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.118 & 0.354 & 0.601 & 0.061 & 0.296 & 0.596 & 0.590 & 0.645 & \underline{0.694} \\
# FAC-VAE & 0.155 & 0.369 & 0.578 & 0.064 & 0.289 & 0.572 & \underline{0.601} & \underline{0.646} & 0.689 \\
# TC-VAE & 0.217 & 0.384 & 0.546 & 0.123 & 0.323 & 0.539 & 0.544 & 0.590 & 0.639 \\
# VD-VAE & 0.120 & 0.337 & 0.566 & 0.054 & 0.270 & 0.557 & 0.586 & 0.632 & 0.675 \\
# DiffWave & 0.113 & \underline{0.386} & \underline{0.680} & \underline{0.194} & \underline{0.456} & 0.695 & 0.245 & 0.442 & 0.618 \\
# VDWave & 0.106 & 0.379 & 0.679 & 0.169 & 0.438 & \underline{0.695} & 0.203 & 0.418 & 0.619 \\
# WaveNet & \underline{0.250} & 0.367 & 0.506 & 0.105 & 0.304 & 0.540 & 0.232 & 0.339 & 0.465 \\
# \textbf{VABAM} & \textbf{0.821} & \textbf{0.828} & \textbf{0.835} & \textbf{0.795} & \textbf{0.805} & \textbf{0.815} & \textbf{0.906} & \textbf{0.907} & \textbf{0.908} \\
#  &  &  &  &  &  &  &  &  &  \\
# \textbf{VitalDB – ECG} &  &  &  &  &  &  &  &  &  \\
# C-VAE & 0.101 & 0.313 & 0.538 & 0.040 & 0.229 & 0.506 & 0.511 & 0.582 & 0.640 \\
# FAC-VAE & 0.075 & 0.300 & 0.561 & 0.039 & 0.240 & 0.530 & 0.413 & 0.539 & 0.638 \\
# TC-VAE & 0.290 & \underline{0.411} & 0.514 & 0.158 & 0.329 & 0.490 & \underline{0.599} & \underline{0.617} & 0.635 \\
# VD-VAE & 0.094 & 0.318 & 0.562 & 0.056 & 0.260 & 0.525 & 0.326 & 0.494 & 0.628 \\
# DiffWave & 0.103 & 0.353 & 0.623 & 0.332 & 0.481 & \underline{0.608} & 0.128 & 0.378 & 0.630 \\
# VDWave & 0.102 & 0.353 & \underline{0.625} & \underline{0.333} & \underline{0.483} & \textbf{0.610} & 0.126 & 0.381 & \underline{0.641} \\
# WaveNet & \underline{0.363} & 0.409 & 0.459 & 0.155 & 0.298 & 0.426 & 0.444 & 0.471 & 0.500 \\
# \textbf{VABAM} & \textbf{0.593} & \textbf{0.618} & \textbf{0.644} & \textbf{0.453} & \textbf{0.516} & 0.578 & \textbf{0.764} & \textbf{0.766} & \textbf{0.768} \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Comparison between the main model and benchmark models (Supplementary file)

# %%
import pandas as pd
import re

# === Load CSV ===
df = pd.read_csv('./EvalResults/SummaryTables/BenchCompTabs.csv')
df_noms = pd.read_csv('./EvalResults/SummaryTables/BenchCompTabs_NOMS.csv')

df = df.rename(columns={'MS':'SF', 'MP':'SP'})
df_noms = df_noms.rename(columns={'MS':'SF', 'MP':'SP'})

# === 모델명 정규화 ===
df["Model"] = df["Model"].str.replace(r".*SKZFC.*", "VABAM", regex=True)

def normalize_model(s: str):
    if isinstance(s, float):
        return s
    if s.startswith("ConVAE"):   return "C-VAE"
    if s.startswith("FACVAE"):   return "FAC-VAE"
    if s.startswith("TCVAE"):    return "TC-VAE"
    if s.startswith("VDVAE"):    return "VD-VAE"
    if s.startswith("DiffWave"): return "DiffWave"
    if s.startswith("VDWave"):   return "VDWave"
    if s.startswith("Wavenet"):  return "WaveNet"
    return s

df["Model"] = df["Model"].map(normalize_model)
df["Type"] = df["Type"].replace({"ART": "ABP", "II": "ECG"})
metric_map = {
    "fft":              "Fast Fourier Transform",
    "matching_pursuit": "Discrete Cosine Transform",
    "welch_evo":        "Welch-based Spectral Evolution"
}
df["MetricLabel"] = df["MetricType"].map(metric_map)

detail_cols     = ["SF", "SP", "AC", "SS", "RA"]
iscore_cols     = ["ISCOREhm", "ISCOREgm", "ISCOREam"]
all_metric_cols = detail_cols + iscore_cols

# df_noms 동일 전처리
df_noms["Model"] = df_noms["Model"].str.replace(r".*SKZFC.*", "VABAM", regex=True)
df_noms["Model"] = df_noms["Model"].map(normalize_model)
df_noms["Type"]  = df_noms["Type"].replace({"ART": "ABP", "II": "ECG"})
df_noms["MetricLabel"] = df_noms["MetricType"].map(metric_map)
for c in ["Source", "Type", "MetricLabel", "Model"]:
    if c not in df_noms.columns:
        df_noms[c] = pd.NA

def lookup_noms_values(source, typ, metric_label):
    sub = df_noms[
        (df_noms["Source"]      == source) &
        (df_noms["Type"]        == typ) &
        (df_noms["MetricLabel"] == metric_label) &
        (df_noms["Model"]       == "VABAM")
    ]
    if sub.empty:
        return {}
    r = sub.iloc[0]
    return {
        "ISCOREam": r["ISCOREam"] if "ISCOREam" in r and pd.notna(r["ISCOREam"]) else None,
        "ISCOREgm": r["ISCOREgm"] if "ISCOREgm" in r and pd.notna(r["ISCOREgm"]) else None,
        "ISCOREhm": r["ISCOREhm"] if "ISCOREhm" in r and pd.notna(r["ISCOREhm"]) else None,
    }

source_list       = df["Source"].dropna().unique()
type_list         = df["Type"].dropna().unique()
metric_type_order = ["Fast Fourier Transform", "Discrete Cosine Transform", "Welch-based Spectral Evolution"]
model_order       = ["C-VAE","FAC-VAE","TC-VAE","VD-VAE","DiffWave","VDWave","WaveNet","VABAM"]
metric_abbr = {
    "Fast Fourier Transform":         "FFT",
    "Discrete Cosine Transform":      "DCT",
    "Welch-based Spectral Evolution": "WSE"
}

# 순위 기호
BEST_SYMBOL   = r"$\dagger$"   # † : 1위
SECOND_SYMBOL = r"$\ddagger$"  # ‡ : 2위

def create_table_for_metric_type(metric_type, metric_df):
    all_rows      = []
    first_dataset = True

    for s in source_list:
        for t in type_list:
            sub = metric_df[(metric_df["Source"]==s) & (metric_df["Type"]==t)].copy()
            if sub.empty:
                continue

            if not first_dataset:
                all_rows.append([""] * (1 + len(all_metric_cols)))

            # 데이터셋 헤더 — bold 없음
            dataset_header = [f"{s} -- {t}"] + [""] * len(all_metric_cols)
            all_rows.append(dataset_header)

            sub["Model"] = pd.Categorical(sub["Model"], categories=model_order, ordered=True)
            sub = sub.sort_values("Model")

            style_map = {}
            for col in all_metric_cols:
                if col in sub.columns:
                    vals      = sub[col].dropna()
                    order_idx = vals.sort_values(ascending=False).index.tolist()
                    style_map[col] = {
                        "first":  sub.loc[order_idx[0], "Model"] if len(order_idx) > 0 else None,
                        "second": sub.loc[order_idx[1], "Model"] if len(order_idx) > 1 else None,
                    }

            noms_iscores = lookup_noms_values(s, t, metric_type)

            for _, row_data in sub.iterrows():
                model = row_data["Model"]

                # VABAM 모델명 — bold 없음
                model_cell = (
                    r"\makecell[l]{VABAM\\\footnotesize(no SF)}"
                    if model == "VABAM" else model
                )
                row = [model_cell]

                # 상세 Metrics — bold/underline → †/‡
                for col in detail_cols:
                    if col in row_data and pd.notna(row_data[col]):
                        val_fmt = f"{row_data[col]:.3f}"
                        if col in style_map and model == style_map[col]["first"]:
                            row.append(f"{val_fmt}{BEST_SYMBOL}")
                        elif col in style_map and model == style_map[col]["second"]:
                            row.append(f"{val_fmt}{SECOND_SYMBOL}")
                        else:
                            row.append(val_fmt)
                    else:
                        row.append("-")

                # ISCORE 컬럼 — bold/underline → †/‡
                for col in iscore_cols:
                    if col in row_data and pd.notna(row_data[col]):
                        main_val = f"{row_data[col]:.3f}"
                        if col in style_map and model == style_map[col]["first"]:
                            main_val_styled = f"{main_val}{BEST_SYMBOL}"
                        elif col in style_map and model == style_map[col]["second"]:
                            main_val_styled = f"{main_val}{SECOND_SYMBOL}"
                        else:
                            main_val_styled = main_val
                    else:
                        main_val_styled = "-"

                    if model == "VABAM":
                        noms_val = noms_iscores.get(col, None)
                        if noms_val is not None:
                            cell = f"\\makecell{{{main_val_styled}\\\\\\footnotesize({noms_val:.3f})}}"
                        else:
                            cell = main_val_styled
                        row.append(cell)
                    else:
                        row.append(main_val_styled)

                all_rows.append(row)
            first_dataset = False

    return all_rows

all_latex_tables = []

for metric_type in metric_type_order:
    metric_df = df[df["MetricLabel"] == metric_type].copy()
    if metric_df.empty:
        continue

    table_rows = create_table_for_metric_type(metric_type, metric_df)

    col_tuples = [("Dataset -- Signal", "Model")]
    for col in detail_cols:
        col_tuples.append(("Metrics", col))
    for col in ["HM", "GM", "AM"]:
        col_tuples.append(("ISCORE", col))
    columns = pd.MultiIndex.from_tuples(col_tuples)

    result_df  = pd.DataFrame(table_rows, columns=columns)
    col_format = "l|ccccc|ccc"

    latex = result_df.to_latex(
        index=False,
        escape=False,
        multicolumn=True,
        multicolumn_format="c",
        column_format=col_format,
        caption=(
            f"\\textbf{{Detailed comparison of ABP and ECG synthesis on MIMIC and VitalDB datasets using the {metric_abbr[metric_type]}.}} "
            "Reported metrics include waveform shape factorization (SF~$\\uparrow$), "
            "shape preservation (SP~$\\uparrow$), "
            "amplitude modulation controllability (AC~$\\uparrow$), "
            "spectral similarity (SS~$\\uparrow$), and reconstruction accuracy (RA~$\\uparrow$), "
            "along with three aggregated ISCORE measures---AM, GM, and HM. "
            "For VABAM, parentheses in the ISCORE columns indicate scores computed without SF. "  # \textbf{VABAM} → VABAM
            "$\\dagger$ and $\\ddagger$ denote the best and second-best results, respectively."    # Boldface/underlining → 기호
        ),
        label=f"tab:detailed_metrics_comparison_{metric_type.lower().replace(' ', '_')}"
    )

    latex = latex.replace("\\begin{table}", "\\begin{table}[!htbp]")
    latex = latex.replace("& \\multicolumn{5}{c}{Metrics}", "& \\multicolumn{5}{c|}{Metrics}")
    latex_with_setup = "\\captionsetup{font=footnotesize, margin=-12pt}\n" + latex

    all_latex_tables.append(latex_with_setup)

for i, table in enumerate(all_latex_tables):
    if i > 0:
        print("\n\\clearpage\n")
    print(table)
# Out:
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Detailed comparison of ABP and ECG synthesis on MIMIC and VitalDB datasets using the FFT.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. For VABAM, parentheses in the ISCORE columns indicate scores computed without SF. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:detailed_metrics_comparison_fast_fourier_transform}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.309 & 0.080 & 0.628$\ddagger$ & 0.604 & 0.982 & 0.250 & 0.392 & 0.521 \\
# FAC-VAE & 0.339 & 0.076 & 0.578 & 0.620 & 0.987$\ddagger$ & 0.245 & 0.391 & 0.520 \\
# TC-VAE & 0.479$\ddagger$ & 0.020 & 0.615 & 0.596 & 0.984 & 0.089 & 0.322 & 0.539 \\
# VD-VAE & 0.347 & 0.033 & 0.449 & 0.608 & 0.987$\dagger$ & 0.132 & 0.315 & 0.485 \\
# DiffWave & - & 0.940$\ddagger$ & 0.032 & 0.689$\ddagger$ & 0.961 & 0.116 & 0.376 & 0.655 \\
# VDWave & - & 0.947$\dagger$ & 0.029 & 0.691$\dagger$ & 0.961 & 0.106 & 0.368 & 0.657$\ddagger$ \\
# WaveNet & - & 0.217 & 0.305 & 0.637 & 0.967 & 0.381$\ddagger$ & 0.449$\ddagger$ & 0.531 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.999$\dagger$ & 0.691 & 0.892$\dagger$ & 0.605 & 0.978 & \makecell{0.801$\dagger$\\\footnotesize(0.763)} & \makecell{0.817$\dagger$\\\footnotesize(0.777)} & \makecell{0.833$\dagger$\\\footnotesize(0.792)} \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.973$\ddagger$ & 0.018 & 0.714 & 0.420 & 0.425 & 0.079 & 0.295 & 0.510 \\
# FAC-VAE & 0.908 & 0.008 & 0.623 & 0.385 & 0.460 & 0.039 & 0.242 & 0.477 \\
# TC-VAE & 0.832 & 0.143 & 0.744$\ddagger$ & 0.345 & 0.088 & 0.210$\ddagger$ & 0.306 & 0.430 \\
# VD-VAE & 0.481 & 0.044 & 0.547 & 0.429 & 0.482 & 0.160 & 0.299 & 0.396 \\
# DiffWave & - & 0.920$\ddagger$ & 0.031 & 0.883$\ddagger$ & 0.880$\ddagger$ & 0.113 & 0.387$\ddagger$ & 0.678$\ddagger$ \\
# VDWave & - & 0.927$\dagger$ & 0.029 & 0.884$\dagger$ & 0.882$\dagger$ & 0.105 & 0.380 & 0.680$\dagger$ \\
# WaveNet & - & 0.095 & 0.200 & 0.564 & 0.068 & 0.125 & 0.164 & 0.232 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.998$\dagger$ & 0.428 & 0.892$\dagger$ & 0.403 & 0.395 & \makecell{0.528$\dagger$\\\footnotesize(0.472)} & \makecell{0.571$\dagger$\\\footnotesize(0.497)} & \makecell{0.623\\\footnotesize(0.530)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.323 & 0.033 & 0.695$\ddagger$ & 0.698 & 0.977$\dagger$ & 0.135 & 0.348 & 0.545 \\
# FAC-VAE & 0.357 & 0.046 & 0.578 & 0.711 & 0.976$\ddagger$ & 0.174 & 0.366 & 0.534 \\
# TC-VAE & 0.490$\ddagger$ & 0.073 & 0.425 & 0.720 & 0.967 & 0.244 & 0.403$\ddagger$ & 0.535 \\
# VD-VAE & 0.311 & 0.034 & 0.536 & 0.719 & 0.975 & 0.137 & 0.332 & 0.515 \\
# DiffWave & - & 0.929$\ddagger$ & 0.031 & 0.795$\dagger$ & 0.964 & 0.113 & 0.386 & 0.680$\ddagger$ \\
# VDWave & - & 0.932$\dagger$ & 0.029 & 0.791$\ddagger$ & 0.964 & 0.106 & 0.379 & 0.679 \\
# WaveNet & - & 0.103 & 0.263 & 0.691 & 0.966 & 0.250$\ddagger$ & 0.367 & 0.506 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.999$\dagger$ & 0.737 & 0.917$\dagger$ & 0.719 & 0.968 & \makecell{0.851$\dagger$\\\footnotesize(0.821)} & \makecell{0.860$\dagger$\\\footnotesize(0.828)} & \makecell{0.868$\dagger$\\\footnotesize(0.835)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.837$\ddagger$ & 0.028 & 0.695 & 0.557 & 0.871 & 0.123 & 0.381 & 0.598 \\
# FAC-VAE & 0.836 & 0.020 & 0.724 & 0.637 & 0.861 & 0.092 & 0.368 & 0.616 \\
# TC-VAE & 0.758 & 0.111 & 0.537 & 0.579 & 0.829 & 0.330 & 0.465$\ddagger$ & 0.563 \\
# VD-VAE & 0.623 & 0.026 & 0.730$\ddagger$ & 0.612 & 0.877 & 0.113 & 0.364 & 0.574 \\
# DiffWave & - & 0.721$\ddagger$ & 0.028 & 0.852$\dagger$ & 0.893$\dagger$ & 0.103 & 0.353 & 0.623 \\
# VDWave & - & 0.727$\dagger$ & 0.028 & 0.852$\ddagger$ & 0.892$\ddagger$ & 0.102 & 0.353 & 0.625$\ddagger$ \\
# WaveNet & - & 0.217 & 0.295 & 0.627 & 0.695 & 0.363$\ddagger$ & 0.409 & 0.459 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.981$\dagger$ & 0.509 & 0.836$\dagger$ & 0.426 & 0.806 & \makecell{0.644$\dagger$\\\footnotesize(0.593)} & \makecell{0.678$\dagger$\\\footnotesize(0.618)} & \makecell{0.712$\dagger$\\\footnotesize(0.644)} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Detailed comparison of ABP and ECG synthesis on MIMIC and VitalDB datasets using the DCT.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. For VABAM, parentheses in the ISCORE columns indicate scores computed without SF. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:detailed_metrics_comparison_discrete_cosine_transform}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.537 & 0.039 & 0.609$\ddagger$ & 0.622 & 0.982 & 0.156 & 0.378 & 0.558 \\
# FAC-VAE & 0.572 & 0.025 & 0.558 & 0.642 & 0.987$\ddagger$ & 0.107 & 0.346 & 0.557 \\
# TC-VAE & 0.643$\ddagger$ & 0.007 & 0.595 & 0.609 & 0.984 & 0.034 & 0.277 & 0.567 \\
# VD-VAE & 0.557 & 0.015 & 0.444 & 0.631 & 0.987$\dagger$ & 0.070 & 0.298 & 0.527 \\
# DiffWave & - & 0.935$\ddagger$ & 0.045 & 0.769$\dagger$ & 0.961 & 0.156 & 0.420$\ddagger$ & 0.677 \\
# VDWave & - & 0.943$\dagger$ & 0.038 & 0.768$\ddagger$ & 0.961 & 0.136 & 0.404 & 0.678$\ddagger$ \\
# WaveNet & - & 0.085 & 0.474 & 0.744 & 0.967 & 0.246$\ddagger$ & 0.413 & 0.567 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 1.000$\dagger$ & 0.597 & 0.891$\dagger$ & 0.615 & 0.978 & \makecell{0.776$\dagger$\\\footnotesize(0.734)} & \makecell{0.796$\dagger$\\\footnotesize(0.752)} & \makecell{0.816$\dagger$\\\footnotesize(0.770)} \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.971$\ddagger$ & 0.006 & 0.742 & 0.199 & 0.425 & 0.027 & 0.203 & 0.469 \\
# FAC-VAE & 0.908 & 0.006 & 0.644 & 0.168 & 0.460 & 0.029 & 0.195 & 0.437 \\
# TC-VAE & 0.874 & 0.077 & 0.745$\ddagger$ & 0.172 & 0.088 & 0.153 & 0.237 & 0.391 \\
# VD-VAE & 0.638 & 0.023 & 0.556 & 0.216 & 0.482 & 0.093 & 0.243 & 0.383 \\
# DiffWave & - & 0.828$\ddagger$ & 0.156 & 0.905$\ddagger$ & 0.880$\ddagger$ & 0.406$\dagger$ & 0.566$\dagger$ & 0.692$\ddagger$ \\
# VDWave & - & 0.847$\dagger$ & 0.146 & 0.906$\dagger$ & 0.882$\dagger$ & 0.390 & 0.561$\ddagger$ & 0.695$\dagger$ \\
# WaveNet & - & 0.006 & 0.372 & 0.514 & 0.068 & 0.022 & 0.095 & 0.240 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.999$\dagger$ & 0.338 & 0.869$\dagger$ & 0.193 & 0.395 & \makecell{0.390$\ddagger$\\\footnotesize(0.338)} & \makecell{0.468\\\footnotesize(0.387)} & \makecell{0.559\\\footnotesize(0.449)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.599 & 0.016 & 0.700$\ddagger$ & 0.690 & 0.977$\dagger$ & 0.074 & 0.340 & 0.597 \\
# FAC-VAE & 0.618 & 0.017 & 0.593 & 0.702 & 0.976$\ddagger$ & 0.078 & 0.336 & 0.581 \\
# TC-VAE & 0.736$\ddagger$ & 0.036 & 0.435 & 0.716 & 0.967 & 0.148 & 0.381 & 0.578 \\
# VD-VAE & 0.581 & 0.014 & 0.534 & 0.705 & 0.975 & 0.066 & 0.314 & 0.562 \\
# DiffWave & - & 0.919$\ddagger$ & 0.058 & 0.841$\ddagger$ & 0.964 & 0.194$\ddagger$ & 0.456$\ddagger$ & 0.695 \\
# VDWave & - & 0.927$\dagger$ & 0.049 & 0.842$\dagger$ & 0.964 & 0.169 & 0.438 & 0.695$\ddagger$ \\
# WaveNet & - & 0.030 & 0.361 & 0.803 & 0.966 & 0.105 & 0.304 & 0.540 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 1.000$\dagger$ & 0.674 & 0.912$\dagger$ & 0.706 & 0.968 & \makecell{0.829$\dagger$\\\footnotesize(0.795)} & \makecell{0.841$\dagger$\\\footnotesize(0.805)} & \makecell{0.852$\dagger$\\\footnotesize(0.815)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.858 & 0.011 & 0.739$\ddagger$ & 0.403 & 0.871 & 0.049 & 0.298 & 0.576 \\
# FAC-VAE & 0.865$\ddagger$ & 0.010 & 0.730 & 0.518 & 0.861 & 0.048 & 0.310 & 0.597 \\
# TC-VAE & 0.839 & 0.049 & 0.607 & 0.476 & 0.829 & 0.189 & 0.397 & 0.560 \\
# VD-VAE & 0.742 & 0.015 & 0.736 & 0.473 & 0.877 & 0.068 & 0.320 & 0.569 \\
# DiffWave & - & 0.557$\ddagger$ & 0.125 & 0.857$\ddagger$ & 0.893$\dagger$ & 0.332 & 0.481 & 0.608 \\
# VDWave & - & 0.564$\dagger$ & 0.126 & 0.858$\dagger$ & 0.892$\ddagger$ & 0.333$\ddagger$ & 0.483$\ddagger$ & 0.610$\ddagger$ \\
# WaveNet & - & 0.050 & 0.456 & 0.502 & 0.695 & 0.155 & 0.298 & 0.426 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.998$\dagger$ & 0.423 & 0.836$\dagger$ & 0.247 & 0.806 & \makecell{0.508$\dagger$\\\footnotesize(0.453)} & \makecell{0.588$\dagger$\\\footnotesize(0.516)} & \makecell{0.662$\dagger$\\\footnotesize(0.578)} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Detailed comparison of ABP and ECG synthesis on MIMIC and VitalDB datasets using the WSE.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. For VABAM, parentheses in the ISCORE columns indicate scores computed without SF. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:detailed_metrics_comparison_welch-based_spectral_evolution}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.196 & 0.481 & 0.636 & 0.682 & 0.982 & 0.445$\ddagger$ & 0.526 & 0.595 \\
# FAC-VAE & 0.189 & 0.461 & 0.696$\ddagger$ & 0.705$\dagger$ & 0.987$\ddagger$ & 0.442 & 0.531$\ddagger$ & 0.608 \\
# TC-VAE & 0.365$\ddagger$ & 0.191 & 0.665 & 0.690 & 0.984 & 0.419 & 0.501 & 0.579 \\
# VD-VAE & 0.213 & 0.361 & 0.529 & 0.700 & 0.987$\dagger$ & 0.424 & 0.489 & 0.558 \\
# DiffWave & - & 0.905$\ddagger$ & 0.106 & 0.575 & 0.961 & 0.301 & 0.480 & 0.637 \\
# VDWave & - & 0.938$\dagger$ & 0.090 & 0.588 & 0.961 & 0.269 & 0.468 & 0.644$\ddagger$ \\
# WaveNet & - & 0.179 & 0.340 & 0.454 & 0.967 & 0.340 & 0.404 & 0.485 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.927$\dagger$ & 0.863 & 0.905$\dagger$ & 0.703$\ddagger$ & 0.978 & \makecell{0.864$\dagger$\\\footnotesize(0.850)} & \makecell{0.870$\dagger$\\\footnotesize(0.856)} & \makecell{0.875$\dagger$\\\footnotesize(0.862)} \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.880$\ddagger$ & 0.128 & 0.765 & 0.497 & 0.425 & 0.342 & 0.449 & 0.539 \\
# FAC-VAE & 0.853 & 0.077 & 0.724 & 0.501 & 0.460 & 0.253 & 0.405 & 0.523 \\
# TC-VAE & 0.525 & 0.486 & 0.823$\ddagger$ & 0.075 & 0.088 & 0.167 & 0.268 & 0.399 \\
# VD-VAE & 0.443 & 0.322 & 0.639 & 0.638 & 0.482 & 0.473$\ddagger$ & 0.489$\ddagger$ & 0.505 \\
# DiffWave & - & 0.940$\ddagger$ & 0.047 & 0.851$\ddagger$ & 0.880$\ddagger$ & 0.161 & 0.426 & 0.679$\ddagger$ \\
# VDWave & - & 0.954$\dagger$ & 0.033 & 0.856$\dagger$ & 0.882$\dagger$ & 0.120 & 0.393 & 0.681$\dagger$ \\
# WaveNet & - & 0.111 & 0.233 & 0.536 & 0.068 & 0.134 & 0.175 & 0.237 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.942$\dagger$ & 0.599 & 0.907$\dagger$ & 0.494 & 0.395 & \makecell{0.596$\dagger$\\\footnotesize(0.546)} & \makecell{0.631$\dagger$\\\footnotesize(0.571)} & \makecell{0.667\\\footnotesize(0.599)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# C-VAE & 0.181 & 0.330 & 0.710$\ddagger$ & 0.757 & 0.977$\dagger$ & 0.406 & 0.500 & 0.591 \\
# FAC-VAE & 0.190 & 0.360 & 0.624 & 0.795$\ddagger$ & 0.976$\ddagger$ & 0.419 & 0.506$\ddagger$ & 0.589 \\
# TC-VAE & 0.231$\ddagger$ & 0.350 & 0.457 & 0.783 & 0.967 & 0.428$\ddagger$ & 0.489 & 0.558 \\
# VD-VAE & 0.168 & 0.352 & 0.596 & 0.779 & 0.975 & 0.391 & 0.485 & 0.574 \\
# DiffWave & - & 0.857 & 0.081 & 0.572 & 0.964 & 0.245 & 0.442 & 0.618 \\
# VDWave & - & 0.874$\ddagger$ & 0.064 & 0.572 & 0.964 & 0.203 & 0.418 & 0.619$\ddagger$ \\
# WaveNet & - & 0.093 & 0.285 & 0.515 & 0.966 & 0.232 & 0.339 & 0.465 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.845$\dagger$ & 0.887$\dagger$ & 0.931$\dagger$ & 0.846$\dagger$ & 0.968 & \makecell{0.893$\dagger$\\\footnotesize(0.906)} & \makecell{0.894$\dagger$\\\footnotesize(0.907)} & \makecell{0.895$\dagger$\\\footnotesize(0.908)} \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# C-VAE & 0.665$\ddagger$ & 0.257 & 0.731 & 0.702 & 0.871 & 0.536 & 0.598 & 0.645$\ddagger$ \\
# FAC-VAE & 0.602 & 0.170 & 0.756$\ddagger$ & 0.764 & 0.861 & 0.441 & 0.551 & 0.631 \\
# TC-VAE & 0.533 & 0.439 & 0.558 & 0.716 & 0.829 & 0.585$\ddagger$ & 0.599$\ddagger$ & 0.615 \\
# VD-VAE & 0.470 & 0.118 & 0.731 & 0.787 & 0.877 & 0.347 & 0.489 & 0.597 \\
# DiffWave & - & 0.745$\ddagger$ & 0.036 & 0.846$\ddagger$ & 0.893$\dagger$ & 0.128 & 0.378 & 0.630 \\
# VDWave & - & 0.781$\dagger$ & 0.036 & 0.854$\dagger$ & 0.892$\ddagger$ & 0.126 & 0.381 & 0.641 \\
# WaveNet & - & 0.382 & 0.299 & 0.623 & 0.695 & 0.444 & 0.471 & 0.500 \\
# \makecell[l]{VABAM\\\footnotesize(no SF)} & 0.740$\dagger$ & 0.716 & 0.845$\dagger$ & 0.705 & 0.806 & \makecell{0.759$\dagger$\\\footnotesize(0.764)} & \makecell{0.761$\dagger$\\\footnotesize(0.766)} & \makecell{0.762$\dagger$\\\footnotesize(0.768)} \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Sensitivity Metric type 에 따른 디테일 버전 (ISCORE 와 COMPONENTS 통합)

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from textwrap import dedent

# ===== 폰트/행간 옵션 =====
TABLE_FONTSIZE = "\\footnotesize"
ARRAY_STRETCH  = 0.95

# ===== 칼럼 간격 조정 =====
TABCOLSEP = "2.5pt"

# ===== multirow 세로 중앙 보정 / 행 높이 표준화 =====
MULTIROW_RAISE_EX = -0.8
ROWSTRUT = "\\rule{0pt}{2.2ex}"

# 순위 기호
BEST_SYMBOL = r"$\dagger$"   # † : 최고값

# === 로드 ===
df_sens = pd.read_csv('./EvalResults/SummaryTables/SensitivityDetailTabs.csv')
df_sens.loc[df_sens['IscoreType'] == 'MS', 'IscoreType'] = 'SF'
df_sens.loc[df_sens['IscoreType'] == 'MP', 'IscoreType'] = 'SP'

# === 전처리 매핑 ===
metric_name_map = {
    "fft":              "Fast Fourier Transform",
    "matching_pursuit": "Discrete Cosine Transform",
    "welch_evo":        "Welch-based Spectral Evolution",
}

# 캡션용 약어
metric_abbr = {
    "Fast Fourier Transform":         "FFT",
    "Discrete Cosine Transform":      "DCT",
    "Welch-based Spectral Evolution": "WSE",
}

parameter_latex_map = {
    "J": "$J$", "K": "$K$", "L": "$L$", "N": "$N$", "T": "$T$",
    "window_size": "Window Size", "overlap": "Overlap",
    "n_components": "Metrics", "max_iter": "Max Iter", "tol": "Tolerance",
}

# === 필수 컬럼 체크 ===
required_cols = {
    "Source","Type","Hyperparameter","Setting","IscoreType",
    "mean","n","std","max","min","MetricType"
}
missing = required_cols - set(df_sens.columns)
if missing:
    raise ValueError(f"Missing required columns in CSV: {missing}")

# === Type 표준화 ===
def normalize_signal_type(x):
    s = str(x).strip()
    u = s.upper()
    if u in {"ART", "ABP"}:
        return "ABP"
    if u in {"II", "ECG"}:
        return "ECG"
    return s

df_sens["Type"] = df_sens["Type"].map(normalize_signal_type)

# === 전처리 ===
df_sens["MetricType"] = df_sens["MetricType"].map(lambda x: metric_name_map.get(x, x))
df_sens["SourceType"] = df_sens["Source"] + " : " + df_sens["Type"]

def normalize_iscore_type(s: str) -> str:
    s = str(s).upper().strip()
    s = s.replace("ISCORE", "").strip()
    repl = {"ISCOREAM": "AM", "ISCOREGM": "GM", "ISCOREHM": "HM"}
    return repl.get(s, s)

df_sens["IscoreType"] = df_sens["IscoreType"].map(normalize_iscore_type)

def latex_escape(s: str) -> str:
    if not isinstance(s, str):
        s = str(s)
    return (s.replace("&","\\&").replace("%","\\%").replace("#","\\#")
             .replace("_","\\_").replace("{","\\{").replace("}","\\}")
             .replace("~","\\textasciitilde ").replace("^","\\textasciicircum "))

def format_parameter(param: str) -> str:
    if param in parameter_latex_map:
        return parameter_latex_map[param]
    if isinstance(param, str) and len(param) == 1 and param.isalpha():
        return f"${param}$"
    return latex_escape(str(param))

# === 두 줄 표기: mean / (std) — bold 제거, 기호 사용 ===
def fmt_val_multiline(m, s, best=False):
    if pd.isna(m):
        return "-"
    mean_str = f"{m:.3f}"
    if best:
        mean_str = f"{mean_str}{BEST_SYMBOL}"   # ← \textbf 대신 † 기호
    if pd.isna(s):
        return "\\begin{tabular}{@{}c@{}} " + mean_str + " \\end{tabular}"
    std_str = f"{s:.3f}"
    return "\\begin{tabular}{@{}c@{}} " + mean_str + " \\\\ (" + std_str + ") \\end{tabular}"

# === MetricType별 + 지정 키 묶음 집계 ===
def aggregate_by_metric_and_keys(df: pd.DataFrame, metric_type: str, metric_keys):
    df_m = df[df["MetricType"] == metric_type]
    out_list = []
    for key in metric_keys:
        sub = df_m[df_m["IscoreType"] == key].copy()
        if sub.empty:
            continue
        sub["TotalSum"] = sub["mean"] * sub["n"]
        agg = (
            sub.groupby(["Source","Type","Hyperparameter","Setting"], as_index=False)
               .agg(TotalSum=("TotalSum","sum"),
                    n=("n","sum"),
                    std=("std","mean"),
                    max=("max","max"),
                    min=("min","min"))
        )
        agg["mean"] = agg["TotalSum"] / agg["n"]
        agg.drop(columns=["TotalSum"], inplace=True)
        agg["IscoreType"] = key
        out_list.append(agg)

    if not out_list:
        return pd.DataFrame(columns=["Source","Type","Hyperparameter","Setting","n","std","max","min","mean","IscoreType","SourceType"])

    out = pd.concat(out_list, ignore_index=True)
    out["SourceType"] = out["Source"] + " : " + out["Type"]
    preferred_order = ["MIMIC : ABP","MIMIC : ECG","VitalDB : ABP","VitalDB : ECG"]
    present = [st for st in preferred_order if st in out["SourceType"].unique().tolist()]
    others  = [st for st in out["SourceType"].unique().tolist() if st not in present]
    col_labels = present + others
    out["SourceType"] = pd.Categorical(out["SourceType"], categories=col_labels, ordered=True)
    out.sort_values(["SourceType","Hyperparameter","Setting","IscoreType"], inplace=True)
    return out

# === 파라미터별 multirow 통합 테이블 빌더 ===
def build_table_unified(metric_keys, sens_agg, method_name):
    if sens_agg.empty:
        return ""
    exist = [k for k in metric_keys if k in sens_agg["IscoreType"].unique().tolist()]
    if not exist:
        return ""

    groups = sens_agg.groupby("SourceType")
    all_rows  = []
    prev_source = None

    total_cols         = 4 + len(exist)
    type_rule_full     = f"\\cmidrule(lr){{1-{total_cols}}}"
    param_rule_from_param = f"\\cmidrule(lr){{3-{total_cols}}}"

    for source_type, group in groups:
        source, signal_type = source_type.split(" : ")

        if prev_source is not None and source != prev_source:
            all_rows.append("\\midrule")
        elif prev_source is not None:
            all_rows.append(type_rule_full)
        prev_source = source

        block = group[group["IscoreType"].isin(exist)].copy()
        piv = block.pivot_table(
            index=["Hyperparameter","Setting"],
            columns="IscoreType",
            values=["mean","std"],
            aggfunc="first"
        )
        cols_present = [c for c in exist if ("mean", c) in piv.columns]
        if not cols_present:
            continue

        hp_set_idx         = list(piv.index)
        total_rows_in_group = len(hp_set_idx)

        param_groups = {}
        for i, (hp, st) in enumerate(hp_set_idx):
            if hp not in param_groups:
                param_groups[hp] = []
            param_groups[hp].append(i)

        # best_mask: bold 대신 † 기호 표시용
        best_mask_by_col = {c: [False]*len(hp_set_idx) for c in cols_present}
        for c in cols_present:
            for hp, idxs in param_groups.items():
                vals = [(i, piv[("mean", c)].iloc[i]) for i in idxs if pd.notna(piv[("mean", c)].iloc[i])]
                if not vals:
                    continue
                best_i = max(vals, key=lambda t: t[1])[0]
                best_mask_by_col[c][best_i] = True

        prev_hp = None
        for i, (hp, st) in enumerate(hp_set_idx):
            if prev_hp is not None and hp != prev_hp:
                all_rows.append(param_rule_from_param)

            if i == 0:
                VERTICAL_OFFSET = 6.
                dynamic_raise = MULTIROW_RAISE_EX * ((total_rows_in_group - 1) / 2.0) - VERTICAL_OFFSET
                source_cell = (
                    f"\\multirow[c]{{{total_rows_in_group}}}{{*}}[{dynamic_raise:.2f}ex]"
                    f"{{{latex_escape(source)}}}"
                )
                type_cell = (
                    f"\\multirow[c]{{{total_rows_in_group}}}{{*}}[{dynamic_raise:.2f}ex]"
                    f"{{{latex_escape(signal_type)}}}"
                )
            else:
                source_cell = ""
                type_cell   = ""

            prev_hp = hp

            cells = [
                source_cell,
                type_cell,
                "\\multicolumn{1}{c}{" + ROWSTRUT + " " + format_parameter(str(hp)) + "}",
                ROWSTRUT + " " + latex_escape(str(st))
            ]

            for c in metric_keys:
                if c in cols_present:
                    m = piv[("mean", c)].iloc[i]
                    s = piv[("std",  c)].iloc[i] if ("std", c) in piv.columns else np.nan
                    is_best  = best_mask_by_col.get(c, [False]*len(hp_set_idx))[i]
                    val_tex  = fmt_val_multiline(m, s, best=is_best)   # ← bold=False, best= 기호 여부
                    cells.append(ROWSTRUT + " " + val_tex)
                else:
                    cells.append(ROWSTRUT + " -")

            all_rows.append(" & ".join(cells) + " \\\\")

    # 헤더
    comp_keys    = ["SF","SP","AC","SS","RA"]
    iscore_keys  = ["HM","GM","AM"]
    comp_present   = [k for k in comp_keys   if k in metric_keys]
    iscore_present = [k for k in iscore_keys if k in metric_keys]

    col_format = "cccc|" + "c"*len(comp_present) + "|" + "c"*len(iscore_present)

    header_top = (
        "\\multicolumn{4}{c|}{} & "
        f"\\multicolumn{{{len(comp_present)}}}{{c|}}{{Metrics}} & "
        f"\\multicolumn{{{len(iscore_present)}}}{{c}}{{ISCORE}} \\\\"
    )
    header_second = (
        "Dataset & Signal & "
        "Parameter & "
        "\\multicolumn{1}{c|}{Setting} & "
        + " & ".join(comp_present + iscore_present)
        + " \\\\"
    )

    header_lines  = ["\\toprule", header_top, header_second, "\\midrule"]
    table_content = "\n".join(header_lines + all_rows + ["\\bottomrule"])

    abbr         = metric_abbr.get(method_name, method_name)   # FFT / DCT / WSE
    label_suffix = method_name.lower().replace(" ", "_")

    cap = (
        f"\\textbf{{Hyperparameter sensitivity analysis for the {abbr}.}} "
        "Reported metrics include waveform shape factorization (SF~$\\uparrow$), "
        "shape preservation (SP~$\\uparrow$), "
        "amplitude modulation controllability (AC~$\\uparrow$), "
        "spectral similarity (SS~$\\uparrow$), and reconstruction accuracy (RA~$\\uparrow$), "
        "along with three aggregated ISCORE measures---AM, GM, and HM. "
        "Results are presented as mean~(s.d.) across independent experiments for each parameter setting. "
        "$\\dagger$ indicates the best-performing setting within each parameter group."   # ← Boldface → †
    )
    label = f"tab:sensitivity_unified_{label_suffix}"

    fontsize_cmd     = (TABLE_FONTSIZE + "\n") if TABLE_FONTSIZE else ""
    arraystretch_cmd = f"\\renewcommand{{\\arraystretch}}{{{ARRAY_STRETCH}}}\n" if ARRAY_STRETCH != 1.0 else ""
    tabcolsep_cmd    = f"\\setlength{{\\tabcolsep}}{{{TABCOLSEP}}}\n" if TABCOLSEP else ""

    return "\n".join([
        "\\captionsetup{font=footnotesize, margin=-12pt}",
        "\\begin{table}[!htbp]",
        "\\centering",
        fontsize_cmd + arraystretch_cmd + tabcolsep_cmd,
        f"\\caption{{{cap}}}",
        f"\\label{{{label}}}",
        f"\\begin{{tabular}}{{{col_format}}}",
        table_content,
        "\\end{tabular}",
        "\\end{table}"
    ])

# === 통합 컬럼 순서 & 출력 ===
unified_keys = ["SF","SP","AC","SS","RA","HM","GM","AM"]
method_order = ["Fast Fourier Transform", "Discrete Cosine Transform", "Welch-based Spectral Evolution"]

latex_blocks = []
for method in method_order:
    sens_agg_unified = aggregate_by_metric_and_keys(df_sens, method, unified_keys)
    t_unified = build_table_unified(unified_keys, sens_agg_unified, method_name=method)
    if t_unified:
        latex_blocks.append(t_unified)

def join_with_clearpages(blocks):
    return ("\n\n\\clearpage\n\n").join([b for b in blocks if b])

print("% --- Auto-generated unified sensitivity tables (parameter-wise multirow) ---")
print(join_with_clearpages(latex_blocks))
# Out:
# % --- Auto-generated unified sensitivity tables (parameter-wise multirow) ---
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \centering
# \footnotesize
# \renewcommand{\arraystretch}{0.95}
# \setlength{\tabcolsep}{2.5pt}
#
# \caption{\textbf{Hyperparameter sensitivity analysis for the FFT.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. Results are presented as mean~(s.d.) across independent experiments for each parameter setting. $\dagger$ indicates the best-performing setting within each parameter group.}
# \label{tab:sensitivity_unified_fast_fourier_transform}
# \begin{tabular}{cccc|ccccc|ccc}
# \toprule
# \multicolumn{4}{c|}{} & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Dataset & Signal & Parameter & \multicolumn{1}{c|}{Setting} & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.660 \\ (0.082) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.852 \\ (0.062) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.698 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.946 \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.808 \\ (0.034) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.820 \\ (0.031) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.831 \\ (0.027) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.748$\dagger$ \\ (0.058) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.853$\dagger$ \\ (0.096) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.723$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.842$\dagger$ \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.850$\dagger$ \\ (0.031) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.858$\dagger$ \\ (0.029) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.710 \\ (0.077) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.866$\dagger$ \\ (0.049) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.714 \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.958 \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.831$\dagger$ \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.840$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.850$\dagger$ \\ (0.026) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.736$\dagger$ \\ (0.092) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.825 \\ (0.149) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.715$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.830 \\ (0.052) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.839 \\ (0.049) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.849 \\ (0.046) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.752$\dagger$ \\ (0.043) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.914$\dagger$ \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.707 \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.961 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.850$\dagger$ \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.858$\dagger$ \\ (0.016) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.867$\dagger$ \\ (0.015) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.685 \\ (0.091) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.791 \\ (0.064) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.722$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.963$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.822 \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.832 \\ (0.031) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.990 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.485$\dagger$ \\ (0.140) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.787 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.453 \\ (0.058) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.799 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.633$\dagger$ \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.669 \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.703 \\ (0.016) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.991$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.460 \\ (0.096) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.817$\dagger$ \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.456$\dagger$ \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.808$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.633 \\ (0.029) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.670$\dagger$ \\ (0.025) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.707$\dagger$ \\ (0.021) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.989 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.463 \\ (0.101) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.797 \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.458$\dagger$ \\ (0.045) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.629 \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.666 \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.702 \\ (0.013) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.994$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.480$\dagger$ \\ (0.131) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.828$\dagger$ \\ (0.053) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.451 \\ (0.028) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.639$\dagger$ \\ (0.043) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.677$\dagger$ \\ (0.037) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.713$\dagger$ \\ (0.030) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.989 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.555$\dagger$ \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.830$\dagger$ \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.423 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.655$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.688$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.720$\dagger$ \\ (0.012) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.993$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.382 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.785 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.488$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.807$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.611 \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.651 \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.691 \\ (0.001) \end{tabular} \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.594 \\ (0.132) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.851$\dagger$ \\ (0.087) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.639$\dagger$ \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.960 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.769 \\ (0.054) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.790 \\ (0.047) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.809 \\ (0.040) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.654$\dagger$ \\ (0.065) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.815 \\ (0.099) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.594 \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.772$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.790$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.809$\dagger$ \\ (0.028) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.632 \\ (0.090) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.837$\dagger$ \\ (0.077) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.613$\dagger$ \\ (0.034) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.970 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.773$\dagger$ \\ (0.037) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.792$\dagger$ \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811$\dagger$ \\ (0.029) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.639$\dagger$ \\ (0.103) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.806 \\ (0.140) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.600 \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.766 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.786 \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.805 \\ (0.038) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.697$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.903$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.599 \\ (0.031) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.973 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.801$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.818$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.834$\dagger$ \\ (0.002) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.572 \\ (0.074) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.751 \\ (0.042) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.619$\dagger$ \\ (0.043) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.976$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.741 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.762 \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.783 \\ (0.007) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.981 \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.688$\dagger$ \\ (0.300) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.836 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.269 \\ (0.166) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.361 \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.453 \\ (0.074) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.542 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.627$\dagger$ \\ (0.020) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.998$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.420 \\ (0.043) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.845$\dagger$ \\ (0.059) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.378$\dagger$ \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.387$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.510$\dagger$ \\ (0.023) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.553$\dagger$ \\ (0.023) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.606 \\ (0.022) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.990 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.552$\dagger$ \\ (0.234) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.832 \\ (0.062) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.330 \\ (0.119) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.373 \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.482 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.547 \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.615$\dagger$ \\ (0.024) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.998$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.423 \\ (0.073) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.862$\dagger$ \\ (0.032) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.367$\dagger$ \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.390$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.508$\dagger$ \\ (0.032) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.553$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.608 \\ (0.026) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.998$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.460 \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.884$\dagger$ \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.390$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.371 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.521$\dagger$ \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.567$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.621$\dagger$ \\ (0.007) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.987 \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.558$\dagger$ \\ (0.296) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.800 \\ (0.038) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.294 \\ (0.124) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.386$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.460 \\ (0.052) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.532 \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.605 \\ (0.032) \end{tabular} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \centering
# \footnotesize
# \renewcommand{\arraystretch}{0.95}
# \setlength{\tabcolsep}{2.5pt}
#
# \caption{\textbf{Hyperparameter sensitivity analysis for the DCT.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. Results are presented as mean~(s.d.) across independent experiments for each parameter setting. $\dagger$ indicates the best-performing setting within each parameter group.}
# \label{tab:sensitivity_unified_discrete_cosine_transform}
# \begin{tabular}{cccc|ccccc|ccc}
# \toprule
# \multicolumn{4}{c|}{} & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Dataset & Signal & Parameter & \multicolumn{1}{c|}{Setting} & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.592 \\ (0.140) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.848$\dagger$ \\ (0.061) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.686 \\ (0.016) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.946 \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.779 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.797 \\ (0.046) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.815 \\ (0.038) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.671$\dagger$ \\ (0.102) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.845 \\ (0.098) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.702$\dagger$ \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.813$\dagger$ \\ (0.051) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.825$\dagger$ \\ (0.045) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.837$\dagger$ \\ (0.039) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.646$\dagger$ \\ (0.104) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.860$\dagger$ \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.700$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.958 \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.805$\dagger$ \\ (0.044) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.819$\dagger$ \\ (0.037) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.833$\dagger$ \\ (0.030) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.642 \\ (0.162) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.818 \\ (0.150) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.691 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.794 \\ (0.079) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.809 \\ (0.070) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.824 \\ (0.062) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.707$\dagger$ \\ (0.044) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.909$\dagger$ \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.691 \\ (0.016) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.961 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.833$\dagger$ \\ (0.016) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.843$\dagger$ \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.854$\dagger$ \\ (0.013) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.582 \\ (0.125) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.783 \\ (0.063) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.703$\dagger$ \\ (0.016) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.963$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.770 \\ (0.055) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.788 \\ (0.046) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.806 \\ (0.038) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.998 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.405$\dagger$ \\ (0.151) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.330$\dagger$ \\ (0.110) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.799 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.534$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.604$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.667 \\ (0.007) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.999$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.388 \\ (0.076) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.826$\dagger$ \\ (0.029) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.320 \\ (0.103) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.808$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.531 \\ (0.025) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.602 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.668$\dagger$ \\ (0.013) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.998 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.387 \\ (0.101) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811 \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.344$\dagger$ \\ (0.111) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.536$\dagger$ \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.605$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.668$\dagger$ \\ (0.007) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.999$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.409$\dagger$ \\ (0.097) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.833$\dagger$ \\ (0.043) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.282 \\ (0.042) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.524 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.598 \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.667 \\ (0.019) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.999 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.471$\dagger$ \\ (0.045) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.835$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.251 \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.522 \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.601 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.671$\dagger$ \\ (0.009) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.999$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.317 \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.396$\dagger$ \\ (0.078) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.807$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.541$\dagger$ \\ (0.023) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.603$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.664 \\ (0.012) \end{tabular} \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.545 \\ (0.135) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.843$\dagger$ \\ (0.087) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.661$\dagger$ \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.960 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.755$\dagger$ \\ (0.060) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.779$\dagger$ \\ (0.049) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802$\dagger$ \\ (0.039) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.577$\dagger$ \\ (0.070) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.807 \\ (0.104) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.614 \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.752 \\ (0.036) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.774 \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.796 \\ (0.029) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.568$\dagger$ \\ (0.083) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.827$\dagger$ \\ (0.084) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.628 \\ (0.044) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.970 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.754$\dagger$ \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.777$\dagger$ \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.799$\dagger$ \\ (0.028) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.563 \\ (0.118) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.801 \\ (0.140) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.633$\dagger$ \\ (0.049) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.750 \\ (0.053) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.773 \\ (0.047) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.796 \\ (0.041) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.628$\dagger$ \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.899$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.618 \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.973 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.787$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.806$\dagger$ \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.824$\dagger$ \\ (0.007) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.505 \\ (0.071) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.739 \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.640$\dagger$ \\ (0.057) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.976$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.719 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.746 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.772 \\ (0.005) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.627$\dagger$ \\ (0.341) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.816 \\ (0.077) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.158 \\ (0.060) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.361 \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.365 \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.481$\dagger$ \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.592$\dagger$ \\ (0.051) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.332 \\ (0.049) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.837$\dagger$ \\ (0.036) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.176$\dagger$ \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.387$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.370$\dagger$ \\ (0.032) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.451 \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.546 \\ (0.018) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.482$\dagger$ \\ (0.259) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.822 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.171$\dagger$ \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.373 \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.372$\dagger$ \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.468$\dagger$ \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.569$\dagger$ \\ (0.041) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.328 \\ (0.084) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.846$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.168 \\ (0.031) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.390$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.362 \\ (0.051) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.447 \\ (0.042) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.546 \\ (0.026) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.371 \\ (0.028) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.865$\dagger$ \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.194$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.371 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.393$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.470$\dagger$ \\ (0.006) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.560 \\ (0.004) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 1.000$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.491$\dagger$ \\ (0.329) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.796 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.145 \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.386$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.344 \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.453 \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.563$\dagger$ \\ (0.056) \end{tabular} \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \centering
# \footnotesize
# \renewcommand{\arraystretch}{0.95}
# \setlength{\tabcolsep}{2.5pt}
#
# \caption{\textbf{Hyperparameter sensitivity analysis for the WSE.} Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. Results are presented as mean~(s.d.) across independent experiments for each parameter setting. $\dagger$ indicates the best-performing setting within each parameter group.}
# \label{tab:sensitivity_unified_welch-based_spectral_evolution}
# \begin{tabular}{cccc|ccccc|ccc}
# \toprule
# \multicolumn{4}{c|}{} & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Dataset & Signal & Parameter & \multicolumn{1}{c|}{Setting} & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.906$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.856 \\ (0.036) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.857 \\ (0.075) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.781 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.946 \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.865 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.867 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.869 \\ (0.008) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.905 \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.877$\dagger$ \\ (0.030) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.891$\dagger$ \\ (0.067) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.836$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.003) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.893$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.894$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.896$\dagger$ \\ (0.018) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.898 \\ (0.038) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.869 \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.882$\dagger$ \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.810 \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.958 \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.880 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.882 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.883 \\ (0.017) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.920$\dagger$ \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.873$\dagger$ \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.874 \\ (0.107) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.832$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.969$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.890$\dagger$ \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.892$\dagger$ \\ (0.032) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.894$\dagger$ \\ (0.031) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.891 \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.875$\dagger$ \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.931$\dagger$ \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.819$\dagger$ \\ (0.038) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.961 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.892$\dagger$ \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.894$\dagger$ \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.895$\dagger$ \\ (0.021) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.919$\dagger$ \\ (0.017) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.865 \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.828 \\ (0.047) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.816 \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.963$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.874 \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.876 \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.878 \\ (0.019) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{VitalDB} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.847$\dagger$ \\ (0.061) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.658 \\ (0.065) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.801 \\ (0.000) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.622 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.799 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.734 \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.740 \\ (0.023) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.745 \\ (0.023) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.815 \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.670$\dagger$ \\ (0.068) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.823$\dagger$ \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.678$\dagger$ \\ (0.027) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.808$\dagger$ \\ (0.004) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.750$\dagger$ \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.755$\dagger$ \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.759$\dagger$ \\ (0.021) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.819 \\ (0.063) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.659 \\ (0.059) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.810 \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.648 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.737 \\ (0.020) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.743 \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.747 \\ (0.017) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.840$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.680$\dagger$ \\ (0.085) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.828$\dagger$ \\ (0.060) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.681$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.811$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.760$\dagger$ \\ (0.028) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.764$\dagger$ \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.768$\dagger$ \\ (0.025) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.822 \\ (0.076) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.720$\dagger$ \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.839$\dagger$ \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.667$\dagger$ \\ (0.042) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.802 \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.763$\dagger$ \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.766$\dagger$ \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.770$\dagger$ \\ (0.014) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.829$\dagger$ \\ (0.021) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.612 \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.793 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.652 \\ (0.034) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.807$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.727 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.733 \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.738 \\ (0.011) \end{tabular} \\
# \midrule
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ABP} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.925 \\ (0.025) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.758 \\ (0.014) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.862$\dagger$ \\ (0.098) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.711$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.960 \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.831 \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.837 \\ (0.025) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.843 \\ (0.026) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.945$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.826$\dagger$ \\ (0.062) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.846 \\ (0.084) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.692 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.002) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.844$\dagger$ \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.851$\dagger$ \\ (0.024) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.858$\dagger$ \\ (0.024) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.931 \\ (0.018) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.787 \\ (0.052) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.862$\dagger$ \\ (0.067) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.705$\dagger$ \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.970 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.839 \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.845 \\ (0.022) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.851 \\ (0.022) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.952$\dagger$ \\ (0.006) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.836$\dagger$ \\ (0.082) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.830 \\ (0.128) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.686 \\ (0.029) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.982$\dagger$ \\ (0.001) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.841$\dagger$ \\ (0.034) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.849$\dagger$ \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.857$\dagger$ \\ (0.035) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.939$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.842$\dagger$ \\ (0.066) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.919$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.692 \\ (0.023) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.973 \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.859$\dagger$ \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.866$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.873$\dagger$ \\ (0.010) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.937 \\ (0.026) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.765 \\ (0.015) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.784 \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.706$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.976$\dagger$ \\ (0.013) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.820 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.827 \\ (0.008) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.834 \\ (0.009) \end{tabular} \\
# \cmidrule(lr){1-12}
# \multirow[c]{6}{*}[-8.00ex]{Mimic} & \multirow[c]{6}{*}[-8.00ex]{ECG} & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 500 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.902 \\ (0.063) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.809$\dagger$ \\ (0.182) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.858 \\ (0.047) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.268 \\ (0.147) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.361 \\ (0.050) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.473 \\ (0.083) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.560 \\ (0.038) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.640 \\ (0.005) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $C$} & \rule{0pt}{2.2ex} 800 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.942$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.611 \\ (0.035) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.867$\dagger$ \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.492$\dagger$ \\ (0.063) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.387$\dagger$ \\ (0.010) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.589$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.624$\dagger$ \\ (0.019) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.660$\dagger$ \\ (0.020) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 30 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.919 \\ (0.041) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.705$\dagger$ \\ (0.160) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.853 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.371 \\ (0.147) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.373 \\ (0.033) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.526 \\ (0.079) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.586 \\ (0.040) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.644 \\ (0.017) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $J$} & \rule{0pt}{2.2ex} 50 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.948$\dagger$ \\ (0.007) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.621 \\ (0.056) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.885$\dagger$ \\ (0.029) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.511$\dagger$ \\ (0.098) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.390$\dagger$ \\ (0.005) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.598$\dagger$ \\ (0.011) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.634$\dagger$ \\ (0.006) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.671$\dagger$ \\ (0.000) \end{tabular} \\
# \cmidrule(lr){3-12}
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 1 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.947$\dagger$ \\ (0.006) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.647 \\ (0.042) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.901$\dagger$ \\ (0.009) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.436$\dagger$ \\ (0.062) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.371 \\ (0.039) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.573$\dagger$ \\ (0.036) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.616$\dagger$ \\ (0.025) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.660$\dagger$ \\ (0.015) \end{tabular} \\
#  &  & \multicolumn{1}{c}{\rule{0pt}{2.2ex} $\zeta$} & \rule{0pt}{2.2ex} 2 & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.910 \\ (0.046) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.707$\dagger$ \\ (0.200) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.826 \\ (0.038) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.399 \\ (0.213) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.386$\dagger$ \\ (0.012) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.528 \\ (0.100) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.589 \\ (0.053) \end{tabular} & \rule{0pt}{2.2ex} \begin{tabular}{@{}c@{}} 0.645 \\ (0.022) \end{tabular} \\
# \bottomrule
# \end{tabular}
# \end{table}
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_63300\3880253852.py:147: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = sens_agg.groupby("SourceType")
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_63300\3880253852.py:147: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = sens_agg.groupby("SourceType")
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_63300\3880253852.py:147: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   groups = sens_agg.groupby("SourceType")

# %% [markdown]
# ### Ablation studies for ABP and ECG synthesis on MIMIC and VitalDB

# %%
import pandas as pd
import re

# === Load CSV ===
df = pd.read_csv('./EvalResults/SummaryTables/AblCompTabs.csv')
df = df.rename(columns={'MS':'SF', 'MP':'SP'})

# === 모델명 정규화 ===
def normalize_model(s: str):
    if isinstance(s, float):
        return s
    if "SKZFC_" in s:
        return "complete"
    if "FC_" in s:
        return "$\\text{only-}\\boldsymbol{\\uptheta}\\text{-prior}$"
    if "SKZ_" in s:
        return "$\\text{only-}\\mathbf{z}\\text{-prior}$"
    return s

df["Model"] = df["Model"].map(normalize_model)

# === 데이터 전처리 ===
df["Type"] = df["Type"].replace({"ART": "ABP", "II": "ECG"})
metric_map = {
    "fft":              "Fast Fourier Transform",
    "matching_pursuit": "Discrete Cosine Transform",
    "welch_evo":        "Welch-based Spectral Evolution"
}
df["MetricLabel"] = df["MetricType"].map(metric_map)

# === 메트릭 컬럼 정의 ===
detail_cols     = ["SF", "SP", "AC", "SS", "RA"]
iscore_cols     = ["ISCOREhm", "ISCOREgm", "ISCOREam"]
all_metric_cols = detail_cols + iscore_cols

# === 고유값 추출 ===
source_list       = df["Source"].dropna().unique()
type_list         = df["Type"].dropna().unique()
metric_type_order = ["Fast Fourier Transform", "Discrete Cosine Transform", "Welch-based Spectral Evolution"]
model_order       = [
    "$\\text{only-}\\boldsymbol{\\uptheta}\\text{-prior}$",
    "$\\text{only-}\\mathbf{z}\\text{-prior}$",
    "complete"
]
metric_abbr = {
    "Fast Fourier Transform":         "FFT",
    "Discrete Cosine Transform":      "DCT",
    "Welch-based Spectral Evolution": "WSE"
}

# 순위 기호
BEST_SYMBOL   = r"$\dagger$"
SECOND_SYMBOL = r"$\ddagger$"

def create_table_for_metric_type(metric_type, metric_df):
    all_rows      = []
    first_dataset = True

    for s in source_list:
        for t in type_list:
            sub = metric_df[(metric_df["Source"] == s) & (metric_df["Type"] == t)].copy()
            if sub.empty:
                continue

            if not first_dataset:
                all_rows.append([""] * (1 + len(all_metric_cols)))

            # 데이터셋 헤더 — bold 없음
            dataset_header = [f"{s} -- {t}"] + [""] * len(all_metric_cols)
            all_rows.append(dataset_header)

            sub["Model"] = pd.Categorical(sub["Model"], categories=model_order, ordered=True)
            sub = sub.sort_values("Model")

            style_map = {}
            for col in all_metric_cols:
                if col in sub.columns:
                    vals = sub[col].dropna()
                    if len(vals) > 0:
                        order_idx = vals.sort_values(ascending=False).index.tolist()
                        style_map[col] = {
                            "first":  sub.loc[order_idx[0], "Model"] if len(order_idx) > 0 else None,
                            "second": sub.loc[order_idx[1], "Model"] if len(order_idx) > 1 else None,
                        }

            for _, row_data in sub.iterrows():
                model = row_data["Model"]

                # complete 모델명 — bold 없음
                row = [model]

                # 상세 Metrics — bold/underline → †/‡
                for col in detail_cols:
                    if col in row_data and pd.notna(row_data[col]):
                        val_fmt = f"{row_data[col]:.3f}"
                        if col in style_map and model == style_map[col]["first"]:
                            row.append(f"{val_fmt}{BEST_SYMBOL}")
                        elif col in style_map and model == style_map[col]["second"]:
                            row.append(f"{val_fmt}{SECOND_SYMBOL}")
                        else:
                            row.append(val_fmt)
                    else:
                        row.append("-")

                # ISCORE 컬럼 — bold/underline → †/‡
                for col in iscore_cols:
                    if col in row_data and pd.notna(row_data[col]):
                        val_fmt = f"{row_data[col]:.3f}"
                        if col in style_map and model == style_map[col]["first"]:
                            row.append(f"{val_fmt}{BEST_SYMBOL}")
                        elif col in style_map and model == style_map[col]["second"]:
                            row.append(f"{val_fmt}{SECOND_SYMBOL}")
                        else:
                            row.append(val_fmt)
                    else:
                        row.append("-")

                all_rows.append(row)

            first_dataset = False

    return all_rows

all_latex_tables = []

for metric_type in metric_type_order:
    metric_df = df[df["MetricLabel"] == metric_type].copy()
    if metric_df.empty:
        continue

    table_rows = create_table_for_metric_type(metric_type, metric_df)

    col_tuples = [("Dataset -- Signal", "Model")]
    for col in detail_cols:
        col_tuples.append(("Metrics", col))
    for col in ["HM", "GM", "AM"]:
        col_tuples.append(("ISCORE", col))
    columns = pd.MultiIndex.from_tuples(col_tuples)

    result_df  = pd.DataFrame(table_rows, columns=columns)
    col_format = "l|ccccc|ccc"

    latex = result_df.to_latex(
        index=False,
        escape=False,
        multicolumn=True,
        multicolumn_format="c",
        column_format=col_format,
        caption=(
            f"\\textbf{{Ablation study of ABP and ECG synthesis on MIMIC and VitalDB datasets using the {metric_abbr[metric_type]}.}} "
            "This table compares three model variants: "
            "$\\text{only-}\\boldsymbol{\\uptheta}\\text{-prior}$ (frequency-domain prior only), "
            "$\\text{only-}\\mathbf{z}\\text{-prior}$ (latent-space prior only), "
            "and complete (full model with both priors). "
            "Reported metrics include waveform shape factorization (SF~$\\uparrow$), "
            "shape preservation (SP~$\\uparrow$), "
            "amplitude modulation controllability (AC~$\\uparrow$), "
            "spectral similarity (SS~$\\uparrow$), and reconstruction accuracy (RA~$\\uparrow$), "
            "along with three aggregated ISCORE measures---AM, GM, and HM. "
            "$\\dagger$ and $\\ddagger$ denote the best and second-best results, respectively."
        ),
        label=f"tab:ablation_study_{metric_type.lower().replace(' ', '_')}"
    )

    latex = latex.replace("\\begin{table}", "\\begin{table}[!htbp]")
    latex = latex.replace("& \\multicolumn{5}{c}{Metrics}", "& \\multicolumn{5}{c|}{Metrics}")
    latex_with_setup = "\\captionsetup{font=footnotesize, margin=-12pt}\n" + latex

    all_latex_tables.append(latex_with_setup)

for i, table in enumerate(all_latex_tables):
    if i > 0:
        print("\n\\clearpage\n")
    print(table)
# Out:
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Ablation study of ABP and ECG synthesis on MIMIC and VitalDB datasets using the FFT.} This table compares three model variants: $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ (frequency-domain prior only), $\text{only-}\mathbf{z}\text{-prior}$ (latent-space prior only), and complete (full model with both priors). Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:ablation_study_fast_fourier_transform}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.999$\ddagger$ & 0.071 & 0.716 & 0.628$\dagger$ & 0.979$\ddagger$ & 0.261$\ddagger$ & 0.499$\ddagger$ & 0.679 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.999 & 1.000$\dagger$ & 0.911$\dagger$ & 0.004 & 0.971 & 0.021 & 0.328 & 0.777$\ddagger$ \\
# complete & 1.000$\dagger$ & 0.712$\ddagger$ & 0.905$\ddagger$ & 0.565$\ddagger$ & 0.981$\dagger$ & 0.794$\dagger$ & 0.814$\dagger$ & 0.833$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.998$\ddagger$ & 0.320 & 0.860 & 0.412$\dagger$ & 0.368$\ddagger$ & 0.479$\ddagger$ & 0.530$\ddagger$ & 0.592 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.999$\dagger$ & 1.000$\dagger$ & 0.905$\dagger$ & 0.214 & 0.179 & 0.374 & 0.510 & 0.659$\dagger$ \\
# complete & 0.998 & 0.475$\ddagger$ & 0.885$\ddagger$ & 0.380$\ddagger$ & 0.393$\dagger$ & 0.531$\dagger$ & 0.575$\dagger$ & 0.626$\ddagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 1.000$\ddagger$ & 0.366 & 0.880 & 0.735$\dagger$ & 0.966$\dagger$ & 0.688 & 0.744 & 0.789 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.964 & 1.000$\dagger$ & 0.906$\ddagger$ & 0.364 & 0.956 & 0.721$\ddagger$ & 0.788$\ddagger$ & 0.838$\ddagger$ \\
# complete & 1.000$\dagger$ & 0.801$\ddagger$ & 0.930$\dagger$ & 0.710$\ddagger$ & 0.966$\ddagger$ & 0.867$\dagger$ & 0.874$\dagger$ & 0.881$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.991$\dagger$ & 0.368 & 0.871$\ddagger$ & 0.450$\dagger$ & 0.819$\dagger$ & 0.601$\ddagger$ & 0.651 & 0.700 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.988 & 1.000$\dagger$ & 0.909$\dagger$ & 0.254 & 0.747 & 0.597 & 0.702$\ddagger$ & 0.780$\dagger$ \\
# complete & 0.991$\ddagger$ & 0.572$\ddagger$ & 0.865 & 0.431$\ddagger$ & 0.810$\ddagger$ & 0.670$\dagger$ & 0.703$\dagger$ & 0.734$\ddagger$ \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Ablation study of ABP and ECG synthesis on MIMIC and VitalDB datasets using the DCT.} This table compares three model variants: $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ (frequency-domain prior only), $\text{only-}\mathbf{z}\text{-prior}$ (latent-space prior only), and complete (full model with both priors). Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:ablation_study_discrete_cosine_transform}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 1.000 & 0.051 & 0.703$\ddagger$ & 0.627$\dagger$ & 0.979$\ddagger$ & 0.201$\ddagger$ & 0.465$\ddagger$ & 0.672 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 1.000$\dagger$ & 0.999$\dagger$ & 0.666 & 0.010 & 0.971 & 0.048 & 0.365 & 0.729$\ddagger$ \\
# complete & 1.000$\ddagger$ & 0.647$\ddagger$ & 0.900$\dagger$ & 0.598$\ddagger$ & 0.981$\dagger$ & 0.788$\dagger$ & 0.807$\dagger$ & 0.825$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 1.000$\ddagger$ & 0.252 & 0.863$\dagger$ & 0.199$\dagger$ & 0.368$\ddagger$ & 0.361$\ddagger$ & 0.437 & 0.536 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 1.000$\dagger$ & 1.000$\dagger$ & 0.668 & 0.186 & 0.179 & 0.346 & 0.467$\ddagger$ & 0.607$\dagger$ \\
# complete & 0.999 & 0.388$\ddagger$ & 0.854$\ddagger$ & 0.190$\ddagger$ & 0.393$\dagger$ & 0.398$\dagger$ & 0.477$\dagger$ & 0.565$\ddagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 1.000$\ddagger$ & 0.293 & 0.880$\ddagger$ & 0.720$\dagger$ & 0.966$\dagger$ & 0.627 & 0.709 & 0.772 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.992 & 1.000$\dagger$ & 0.653 & 0.331 & 0.956 & 0.657$\ddagger$ & 0.728$\ddagger$ & 0.786$\ddagger$ \\
# complete & 1.000$\dagger$ & 0.757$\ddagger$ & 0.924$\dagger$ & 0.691$\ddagger$ & 0.966$\ddagger$ & 0.850$\dagger$ & 0.859$\dagger$ & 0.868$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.998 & 0.308 & 0.878$\dagger$ & 0.387$\dagger$ & 0.819$\dagger$ & 0.544$\dagger$ & 0.612$\dagger$ & 0.678 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 1.000$\dagger$ & 1.000$\dagger$ & 0.670 & 0.133 & 0.747 & 0.404 & 0.581 & 0.710$\dagger$ \\
# complete & 0.999$\ddagger$ & 0.477$\ddagger$ & 0.863$\ddagger$ & 0.252$\ddagger$ & 0.810$\ddagger$ & 0.529$\ddagger$ & 0.610$\ddagger$ & 0.680$\ddagger$ \\
# \bottomrule
# \end{tabular}
# \end{table}
#
#
# \clearpage
#
# \captionsetup{font=footnotesize, margin=-12pt}
# \begin{table}[!htbp]
# \caption{\textbf{Ablation study of ABP and ECG synthesis on MIMIC and VitalDB datasets using the WSE.} This table compares three model variants: $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ (frequency-domain prior only), $\text{only-}\mathbf{z}\text{-prior}$ (latent-space prior only), and complete (full model with both priors). Reported metrics include waveform shape factorization (SF~$\uparrow$), shape preservation (SP~$\uparrow$), amplitude modulation controllability (AC~$\uparrow$), spectral similarity (SS~$\uparrow$), and reconstruction accuracy (RA~$\uparrow$), along with three aggregated ISCORE measures---AM, GM, and HM. $\dagger$ and $\ddagger$ denote the best and second-best results, respectively.}
# \label{tab:ablation_study_welch-based_spectral_evolution}
# \begin{tabular}{l|ccccc|ccc}
# \toprule
# Dataset -- Signal & \multicolumn{5}{c|}{Metrics} & \multicolumn{3}{c}{ISCORE} \\
# Model & SF & SP & AC & SS & RA & HM & GM & AM \\
# \midrule
# Mimic -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.965$\dagger$ & 0.201 & 0.739 & 0.746$\dagger$ & 0.979$\ddagger$ & 0.514$\ddagger$ & 0.637$\ddagger$ & 0.726 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.942 & 1.000$\dagger$ & 0.924$\dagger$ & 0.045 & 0.971 & 0.188 & 0.519 & 0.776$\ddagger$ \\
# complete & 0.948$\ddagger$ & 0.894$\ddagger$ & 0.920$\ddagger$ & 0.666$\ddagger$ & 0.981$\dagger$ & 0.865$\dagger$ & 0.874$\dagger$ & 0.882$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# Mimic -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.904$\ddagger$ & 0.492 & 0.875 & 0.481$\dagger$ & 0.368$\ddagger$ & 0.551$\ddagger$ & 0.586$\ddagger$ & 0.624$\ddagger$ \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.892 & 1.000$\dagger$ & 0.916$\dagger$ & 0.093 & 0.179 & 0.255 & 0.423 & 0.616 \\
# complete & 0.954$\dagger$ & 0.661$\ddagger$ & 0.906$\ddagger$ & 0.441$\ddagger$ & 0.393$\dagger$ & 0.590$\dagger$ & 0.630$\dagger$ & 0.671$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ABP &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.963$\dagger$ & 0.617 & 0.891 & 0.825$\ddagger$ & 0.966$\dagger$ & 0.829 & 0.841 & 0.852 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.814 & 1.000$\dagger$ & 0.915$\ddagger$ & 0.762 & 0.956 & 0.880$\ddagger$ & 0.885$\ddagger$ & 0.889$\ddagger$ \\
# complete & 0.920$\ddagger$ & 0.908$\ddagger$ & 0.950$\dagger$ & 0.836$\dagger$ & 0.966$\ddagger$ & 0.914$\dagger$ & 0.915$\dagger$ & 0.916$\dagger$ \\
#  &  &  &  &  &  &  &  &  \\
# VitalDB -- ECG &  &  &  &  &  &  &  &  \\
# $\text{only-}\boldsymbol{\uptheta}\text{-prior}$ & 0.855$\dagger$ & 0.638 & 0.870$\ddagger$ & 0.621$\ddagger$ & 0.819$\dagger$ & 0.744$\ddagger$ & 0.753$\ddagger$ & 0.761 \\
# $\text{only-}\mathbf{z}\text{-prior}$ & 0.783 & 1.000$\dagger$ & 0.909$\dagger$ & 0.446 & 0.747 & 0.719 & 0.750 & 0.777$\ddagger$ \\
# complete & 0.836$\ddagger$ & 0.740$\ddagger$ & 0.870 & 0.673$\dagger$ & 0.810$\ddagger$ & 0.779$\dagger$ & 0.783$\dagger$ & 0.786$\dagger$ \\
# \bottomrule
# \end{tabular}
# \end{table}
